# %% [markdown]
# ## Start

# %%
import pandas as pd
import numpy as np

# %%
user="cornell"
password="Pitney@1a"
host="gec-dwh.ctz5iw1v2fh7.us-west-2.rds.amazonaws.com"
db="cornell"

conn = f"mysql+pymysql://{user}:{password}@{host}/{db}"

# %%
from sqlalchemy import create_engine

engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{db}")

# %%
result = engine.execute('show tables in cornell')
for _r in result:
    print(_r)
# Out:
# ('deliver_package_info',)
# ('input_df',)
# ('ne_delivery_data_by_day_2018',)
# ('ne_returns_data_by_day_2018',)
# ('return_package_info',)
# ('return_package_info_update',)
# ('test_df',)

# %%
result = engine.execute('describe deliver_package_info ')
for _r in result:
    print(_r)
# Out:
# ('index', 'bigint(20)', 'YES', 'MUL', None, '')
# ('origindate', 'date', 'YES', '', None, '')
# ('originfacilityzip', 'text', 'YES', '', None, '')
# ('destinationfacilityzip', 'text', 'YES', '', None, '')
# ('count', 'bigint(20)', 'YES', '', None, '')
# ('origin_zip3', 'text', 'YES', '', None, '')
# ('origin_state', 'text', 'YES', '', None, '')
# ('origin_lat', 'text', 'YES', '', None, '')
# ('origin_lng', 'text', 'YES', '', None, '')
# ('dest_zip3', 'text', 'YES', '', None, '')
# ('dest_state', 'text', 'YES', '', None, '')
# ('dest_lat', 'text', 'YES', '', None, '')
# ('dest_lng', 'text', 'YES', '', None, '')

# %% [markdown]
# ### deliver and return datas

# %%
#deliver datas
#deliver datas
result = engine.execute('select origindate,origin_state,origin_zip3,origin_lat,origin_lng,dest_state,dest_zip3,dest_lat,dest_lng,count from deliver_package_info where origin_lat !="''" and dest_lat !="''" and origindate>="2018-08-19" and origindate<="2018-08-23" group by origindate,origin_lat,origin_lng')
delPackage_df = pd.DataFrame(result.fetchall(),columns=['origindate','origin_state','origin_zip3','origin_lat','origin_lng','dest_state','dest_zip3','dest_lat','dest_lng','count'])
delPackage_df
# Out:
#     origindate origin_state origin_zip3        origin_lat         origin_lng  \
# 0   2018-08-19           GA         303  33.7554224110405  -84.3904423185221
# 1   2018-08-19           MD         216   38.795345473114  -76.0826444285563
# 2   2018-08-19           OH         430  40.0879778724422  -82.6129450831437
# 3   2018-08-19           PA         190  40.1269047717822  -75.1256831129385
# 4   2018-08-19           IN         460  40.2490326631515  -85.6604766032736
# 5   2018-08-19           PA         170  40.5266561258918  -77.8269602130124
# 6   2018-08-19           PA         151  40.5804379499168  -79.9554146477495
# 7   2018-08-19           NJ         088  40.6240218011197  -74.8843774239638
# 8   2018-08-19           NY         114  40.7049329101236  -73.7938723442845
# 9   2018-08-19           NY         110  40.7220752067917  -73.7068341419121
# 10  2018-08-19           NY         100  40.7505956027072  -73.9969904238369
# 11  2018-08-19           PA         163  41.4542864255809  -79.6519755218344
# 12  2018-08-19           CT         060   41.791323312423  -72.8538070382769
# 13  2018-08-20           GA         303  33.7554224110405  -84.3904423185221
# 14  2018-08-20           MD         216   38.795345473114  -76.0826444285563
# 15  2018-08-20           DE         197  39.5851778604444  -75.6993444178467
# 16  2018-08-20           OH         430  40.0879778724422  -82.6129450831437
# 66         NY       142  42.8965886623808  -78.8865218406153      2
# 67         RI       029  41.8258558538419  -71.4134288124013      3
#
# [68 rows x 10 columns]

# %% [markdown]
# ### return package

# %%
#return datas
result = engine.execute('select origindate,origin_state,origin_zip3,origin_lat,origin_lng,dest_state,dest_zip3,dest_lat,dest_lng,count from return_package_info where origin_lat !="''" and dest_lat !="''" and origindate>="2018-08-19" and origindate<="2018-08-23" group by origindate,origin_lat,origin_lng')
rePackage_df = pd.DataFrame(result.fetchall(),columns=['origindate','dest_state','dest_zip3','dest_lat','dest_lng','origin_state','origin_zip3','origin_lat','origin_lng','count'])
rePackage_df
# Out:
#      origindate dest_state dest_zip3          dest_lat           dest_lng  \
# 0    2018-08-19         GA       303  33.7554224110405  -84.3904423185221
# 1    2018-08-19         VA       235  36.8517460063432  -76.2800020807876
# 2    2018-08-19         VA       236  37.0458849267273  -76.4679680206234
# 3    2018-08-19         VA       240  37.2706334855373  -79.9411734251418
# 4    2018-08-19         VA       232  37.5392326292499  -77.4374487131616
# 5    2018-08-19         VA       231  37.7104569783371  -77.8364615182062
# 6    2018-08-19         WV       253  38.3510365905497  -81.6282391249495
# 7    2018-08-19         MD       216   38.795345473114  -76.0826444285563
# 8    2018-08-19         VA       220   38.830674055139  -77.2134826436305
# 9    2018-08-19         MD       207  39.1250801086426  -76.8025207519531
# 10   2018-08-19         MD       212  39.2939663221704  -76.6223873270678
# 11   2018-08-19         MD       210  39.4748982668505  -76.2084143365847
# 12   2018-08-19         DE       197  39.5851778604444  -75.6993444178467
# 13   2018-08-19         PA       191  39.9526139495128   -75.183696779919
# 14   2018-08-19         PA       176  40.0730558106315  -76.3141886839793
# 15   2018-08-19         PA       190  40.1269047717822  -75.1256831129385
# 16   2018-08-19         NJ       086  40.2200553459778  -74.7606863536026
# 17   2018-08-19         IN       460  40.2490326631515  -85.6604766032736
# 18   2018-08-19         PA       171  40.2595772715771  -76.8875671218581
# 19   2018-08-19         PA       180  40.4692977017575  -75.6482993536905
# 20   2018-08-19         PA       152         40.473674         -79.955872
# 21   2018-08-19         NJ       070  40.5833124911422  -74.2703150322948
# 22   2018-08-19         PA       150  40.5931045064299  -80.3210143620504
# 23   2018-08-19         NJ       072  40.6705538121771   -74.177558305216
# 24   2018-08-19         NY       117  40.6819634281226  -73.4125545304573
# 25   2018-08-19         NY       115  40.7467145052922  -73.6395425596232
# 26   2018-08-19         NY       113  40.7563418797691  -73.8274802402864
# 27   2018-08-19         NY       101  40.7633090468481  -73.9797878439146
# 28   2018-08-19         NY       106   41.032704037141  -73.7650821954244
# 29   2018-08-19         CT       069  41.0536387488792  -73.5380348358793
# ..          ...        ...       ...               ...                ...
# 275  2018-08-23         NY       112  40.6970240928097  -73.9890018436833
# 276  2018-08-23         NY       115  40.7467145052922  -73.6395425596232
# 277  2018-08-23         NY       113  40.7563418797691  -73.8274802402864
# 278  2018-08-23         NY       101  40.7633090468481  -73.9797878439146
# 279  2018-08-23         NJ       076  40.8890286852354  -74.0457692553894
# 280  2018-08-23         NY       106   41.032704037141  -73.7650821954244
# 26            CA         924  34.0974426269531  -117.292900085449      1
# 27            NJ         088  40.6240218011197  -74.8843774239638      2
# 28            NJ         070  40.5833124911422  -74.2703150322948      1
# 29            NJ         070  40.5833124911422  -74.2703150322948      1
# ..           ...         ...               ...                ...    ...
# 275           NJ         070  40.5833124911422  -74.2703150322948      8
# 276           NJ         070  40.5833124911422  -74.2703150322948      2
# 277           NJ         070  40.5833124911422  -74.2703150322948      2
# 278           MA         014  42.5853946189292  -71.8170603313981      1
# 279           NJ         070  40.5833124911422  -74.2703150322948      3
# 280           PA         170  40.5266561258918  -77.8269602130124      2
# 281           NJ         070  40.5833124911422  -74.2703150322948      3
# 282           MA         014  42.5853946189292  -71.8170603313981      1
# 283           TX         750  32.9602558381961  -96.8380888773413      1
# 284           NJ         088  40.6240218011197  -74.8843774239638      2
# 285           MA         014  42.5853946189292  -71.8170603313981      2
# 286           NJ         070  40.5833124911422  -74.2703150322948      7
# 287           NJ         070  40.5833124911422  -74.2703150322948      1
# 288           NJ         070  40.5833124911422  -74.2703150322948      1
# 289           IN         460  40.2490326631515  -85.6604766032736      2
# 290           NJ         070  40.5833124911422  -74.2703150322948      1
# 291           MA         014  42.5853946189292  -71.8170603313981      1
# 292           NJ         070  40.5833124911422  -74.2703150322948      3
# 293           PA         176  40.0730558106315  -76.3141886839793      1
# 294           NJ         070  40.5833124911422  -74.2703150322948      1
# 295           PA         176  40.0730558106315  -76.3141886839793      1
# 296           NJ         070  40.5833124911422  -74.2703150322948      2
# 297           NJ         070  40.5833124911422  -74.2703150322948      3
# 298           MA         014  42.5853946189292  -71.8170603313981      1
# 299           MA         014  42.5853946189292  -71.8170603313981      1
# 300           NJ         088  40.6240218011197  -74.8843774239638      1
# 301           NJ         070  40.5833124911422  -74.2703150322948      2
# 302           NJ         070  40.5833124911422  -74.2703150322948      4
# 303           NJ         070  40.5833124911422  -74.2703150322948      3
# 304           NH         030  42.8706400439212  -71.6071227268889      1
#
# [305 rows x 10 columns]

# %% [markdown]
# ### hub location

# %%
# hub locations
facility_df=pd.DataFrame()
facility_df['ID']=["F"+str(i) for i in range(101,111)]
facility_df['lat']=[40.272873706173655,44.89515483095407,42.304686965277391,38.563117084832918,40.799492838763541,
                    40.642102443412682,41.622412156211446,42.717481071824182,41.775317822514765,39.637607998749651]
facility_df['lng']=[-78.437189786669663,-70.792749586986645,-77.008752286812296,-77.934078803323573,-80.429785375722489,
                    -81.09876856469576,-75.298832812376659,-72.696958353258665,-71.910726787671877,-75.921949353175265]
facility_df
# facility_df['lat']=[40.272873706173655,44.89515483095407,42.304686965277391,38.563117084832918,40.799492838763541]
# facility_df['lng']=[-78.437189786669663,-70.792749586986645,-77.008752286812296,-77.934078803323573,-80.429785375722489]
# hub locations
# Out:
#      ID        lat        lng
# 0  F101  40.272874 -78.437190
# 1  F102  44.895155 -70.792750
# 2  F103  42.304687 -77.008752
# 3  F104  38.563117 -77.934079
# 4  F105  40.799493 -80.429785
# 5  F106  40.642102 -81.098769
# 6  F107  41.622412 -75.298833
# 7  F108  42.717481 -72.696958
# 8  F109  41.775318 -71.910727
# 9  F110  39.637608 -75.921949

# %% [markdown]
# ## final hub

# %%
finalhub=['F106','F108','F110']
l=[]
for i in range(len(facility_df)):
    if str(facility_df.iloc[i]['ID']) in finalhub:
        l.append(facility_df.iloc[i,:].values)
    facilityfinal_df=pd.DataFrame(l,columns=['ID','lat','lng'])
facilityfinal_df
# Out:
#      ID        lat        lng
# 0  F106  40.642102 -81.098769
# 1  F108  42.717481 -72.696958
# 2  F110  39.637608 -75.921949

# %% [markdown]
# ## delivery initial locations

# %%
Initial_df=pd.DataFrame()
df1=delPackage_df[['origin_zip3','origin_lat','origin_lng','count']]
df2=rePackage_df[['origin_zip3','origin_lat','origin_lng','count']]
initmp_df=df1.append(df2)
initmp_df=initmp_df.reset_index(drop=True)
n=len(initmp_df)

Id=[]
Lat=[]
Lng=[]
Package=[]

iniloc_dic={}
cnt=0

for i in range(0,n):
    zip3=str(initmp_df.iloc[i]['origin_zip3'])
    if zip3 not in iniloc_dic:
        cnt+=1
        d='i'+str(cnt)
        Id.append(iniloc_dic.setdefault(zip3,d))
        Lat.append(float(initmp_df['origin_lat'][i]))
        Lng.append(float(initmp_df['origin_lng'][i]))
        Package.append(float(initmp_df['count'][i]))
Initial_df['ID']=Id
Initial_df['lat']=Lat
Initial_df['lng']=Lng
Initial_df['packages']=Package

Initial_df


# delInitial_df=pd.DataFrame()
# n=len(delPackage_df)
# delId=[]
# delLat=[]
# delLng=[]
# delPakg=[]
# for i in range(0,n):
#     delId.append("i"+str(int(i+1)))
#     delLat.append(float(delPackage_df['origin_lat'][i]))
#     delLng.append(float(delPackage_df['origin_lng'][i]))
#     delPakg.append(delPackage_df['count'][i])
# delInitial_df['ID']=delId
# delInitial_df['lat']=delLat
# delInitial_df['lng']=delLng
# delInitial_df['packages']=delPakg

# delInitial_df
# Out:
#      ID        lat         lng  packages
# 0    i1  33.755422  -84.390442      12.0
# 1    i2  38.795345  -76.082644       2.0
# 2    i3  40.087978  -82.612945      17.0
# 3    i4  40.126905  -75.125683       1.0
# 4    i5  40.249033  -85.660477      33.0
# 5    i6  40.526656  -77.826960       3.0
# 6    i7  40.580438  -79.955415       1.0
# 7    i8  40.624022  -74.884377       1.0
# 8    i9  40.704933  -73.793872       3.0
# 9   i10  40.722075  -73.706834       2.0
# 10  i11  40.750596  -73.996990       1.0
# 11  i12  41.454286  -79.651976      14.0
# 12  i13  41.791323  -72.853807       1.0
# 13  i14  39.585178  -75.699344       1.0
# 14  i15  40.353176  -75.940457       1.0
# 15  i16  30.270605  -97.743398      31.0
# 16  i17  41.292236  -73.760442       1.0
# 17  i18  42.585395  -71.817060       1.0
# 18  i19  40.073056  -76.314189       1.0
# 19  i20  40.583312  -74.270315       2.0
# 20  i21  40.316237  -79.535016       1.0
# 21  i22  39.686555  -76.846106       1.0
# 22  i23  34.097443 -117.292900       1.0
# 23  i24  41.182369  -75.752440       1.0
# 24  i25  35.911301  -77.736250       1.0
# 25  i26  42.870640  -71.607123       1.0
# 26  i27  40.156763  -76.204517       1.0
# 27  i28  32.960256  -96.838089       1.0

# %%
Final_df=pd.DataFrame()
df1=delPackage_df[['dest_zip3','dest_lat','dest_lng','count']]
df2=rePackage_df[['dest_zip3','dest_lat','dest_lng','count']]
fintmp_df=df1.append(df2)
fintmp_df=fintmp_df.reset_index(drop=True)
n=len(fintmp_df)

Id=[]
Lat=[]
Lng=[]
Package=[]

finalloc_dic={}
cnt=0

for i in range(0,n):
    zip3=str(fintmp_df.iloc[i]['dest_zip3'])
    if zip3 not in finalloc_dic:
        cnt+=1
        d='k'+str(cnt)
        Id.append(finalloc_dic.setdefault(zip3,d))
        Lat.append(float(fintmp_df['dest_lat'][i]))
        Lng.append(float(fintmp_df['dest_lng'][i]))
        Package.append(float(fintmp_df['count'][i]))
Final_df['ID']=Id
Final_df['lat']=Lat
Final_df['lng']=Lng
Final_df['packages']=Package

Final_df
# Out:
#      ID        lat        lng  packages
# 0    k1  42.105697 -72.598079      12.0
# 1    k2  40.681963 -73.412555       1.0
# 2    k3  41.344762 -73.068705       1.0
# 3    k4  33.755422 -84.390442       3.0
# 4    k5  42.485950 -71.155370       2.0
# 5    k6  40.220055 -74.760686       1.0
# 6    k7  40.249033 -85.660477      14.0
# 7    k8  42.196872 -71.845387       1.0
# 8    k9  43.530479 -70.921228       1.0
# 9   k10  37.539233 -77.437449       1.0
# 10  k11  43.159143 -77.606819       1.0
# 11  k12  42.647280 -73.751693       2.0
# 12  k13  43.674713 -72.386002       1.0
# 13  k14  41.825856 -71.413429       2.0
# 14  k15  40.126905 -75.125683       1.0
# 15  k16  37.254844 -75.798720       1.0
# 16  k17  39.474898 -76.208414       1.0
# 17  k18  42.896589 -78.886522       2.0
# 18  k19  36.851746 -76.280002       1.0
# 19  k20  37.045885 -76.467968       1.0
# 20  k21  37.270633 -79.941173       2.0
# 21  k22  37.710457 -77.836462       2.0
# 22  k23  38.351037 -81.628239       2.0
# 23  k24  38.795345 -76.082644       1.0
# 24  k25  38.830674 -77.213483       1.0
# 25  k26  39.125080 -76.802521       2.0
# 26  k27  39.293966 -76.622387       1.0
# 27  k28  39.585178 -75.699344       2.0
# 28  k29  39.952614 -75.183697       1.0
# 29  k30  40.073056 -76.314189       3.0
# ..  ...        ...        ...       ...
# 46  k47  43.043578 -76.150704       1.0
# 47  k48  44.849648 -68.845938       3.0
# 48  k49  37.237827 -77.336182       1.0
# 49  k50  38.088397 -78.555481       1.0
# 50  k51  38.938148 -77.164132       1.0
# 51  k52  38.966411 -77.143607       1.0
# 52  k53  39.417475 -74.486369       1.0
# 53  k54  39.551808 -75.352312       2.0
# 54  k55  39.946061 -75.121656       1.0
# 55  k56  40.040989 -75.482167       1.0
# 56  k57  40.069978 -80.650842       1.0
# 57  k58  40.327844 -78.913818       2.0
# 58  k59  40.554738 -78.368392       2.0
# 59  k60  40.697024 -73.989002       4.0
# 60  k61  40.889029 -74.045769       1.0
# 61  k62  40.987951 -80.287803       1.0
# 62  k63  41.454286 -79.651976       2.0
# 63  k64  41.784465 -71.060769       1.0
# 64  k65  43.072754 -70.804060       1.0
# 65  k66  43.097484 -77.338041       1.0
# 110   k73  42.388495  -78.541352       1.0
# 111   k74  38.403648  -78.875703       1.0
# 112   k75  41.345086  -76.894836       1.0
# 113   k76  42.599455  -76.064045       1.0
#
# [114 rows x 4 columns]

# %%
# packageparam=pd.DataFrame()
# n=len(delPackage_df)
# initDelID=np.zeros(n)
# finalDelID=np.zeros(n)
# delPackages=np.zeros(n)
# for i in range(n):
#     finalDelID[i]=201+i
#     delPackages[i]=delPackage_df['count'][i]
# # for j in range(n,n*n)
# #     for k in initDelID:
# #         for i in finalDelID:
            
# packageparam['initID']=initDelID
# packageparam['finalID']=finalDelID
# packageparam['packages']=delPackages
# packageparam

packageparam=pd.DataFrame()
init_ID=[]
final_ID=[]
delPackages=[]
n=len(delPackage_df)
delId=[]
cnt=200
for i in range(0,n):
    zip3=str(delPackage_df.iloc[i]['dest_zip3'])
    delPackages.append(delPackage_df['count'][i])
    final_ID.append(finalloc_dic[zip3])
    
    

packageparam['initID']=delInitial_df['ID']
packageparam['finalID']=final_ID
packageparam['packages']=delPackage_df['count']
packageparam
# Out:
#    initID finalID  packages
# 0      i1      k1        12
# 1      i2      k1         2
# 2      i3      k1        17
# 3      i4      k2         1
# 4      i5      k1        33
# 5      i6      k1         3
# 6      i7      k1         1
# 7      i8      k3         1
# 8      i9      k4         3
# 9     i10      k5         2
# 10    i11      k6         1
# 11    i12      k7        14
# 12    i13      k8         1
# 13    i14      k1         5
# 14    i15      k1         4
# 15    i16      k9         1
# 16    i17      k1        23
# 17    i18      k1        43
# 18    i19      k1         3
# 19    i20      k8         1
# 20    i21      k1         2
# 21    i22     k10         1
# 22    i23      k1        25
# 23    i24     k11         1
# 24    i25      k4      2196
# 25    i26      k8         4
# 26    i27      k1         7
# 27    i28      k1         2
# 28    i29      k1        28
# 29    i30      k1        32
# ..    ...     ...       ...
# 38    i39      k8         7
# 39    i40      k7        31
# 40    i41      k1         5
# 41    i42      k1         1
# 42    i43      k1        18
# 43    i44      k1        28
# 44    i45     k14         2
# 45    i46      k1         5
# 46    i47      k8         1
# 47    i48      k4        17
# 48    i49      k1         6
# 49    i50     k15         1
# 50    i51      k8         1
# 51    i52      k4      2516
# 52    i53      k5         1
# 53    i54      k7         1
# 54    i55      k1         8
# 55    i56      k1         2
# 56    i57      k8         2
# 57    i58      k1        15
# 58    i59      k4         1
# 59    i60      k1        42
# 60    i61     k16         1
# 61    i62      k8         1
# 62    i63      k1         1
# 63    i64     k17         1
# 64    i65      k1        23
# 65    i66      k4         6
# 66    i67     k18         2
# 67    i68     k14         3
#
# [68 rows x 3 columns]

# %% [markdown]
# ## Forlium

# %%
# ! pip install folium

# %%
import folium

# %% [markdown]
# ### Initialize map

# %%
# m = folium.Map(location=[41.9, -97.3],tiles="Mapbox Bright",zoom_start=4)
m = folium.Map(location=[np.mean(df_locations['lat']), np.mean(df_locations['lng'])],tiles="Mapbox Bright",zoom_start=6)

# %% [markdown]
# ### Visualize facility location

# %%
from folium.features import CustomIcon
import os


path = os.getcwd()
hub_image = path+'/hub_icon.png'
finalhub_image = path+'/finalhub_icon.png'

## Customize the facility icon
def add_facility_marker(df,name,m,finallist): 
    path = os.getcwd()
    hub_image = path+'/hub_icon.png'
    finalhub_image = path+'/finalhub_icon.png'
    
    for i in range(len(df)):
#         if name=='final facility':
        if df.iloc[i]['ID'] in finallist:
            icon = CustomIcon(
                finalhub_image,
                icon_size=(20, 20)
            )        
        else:
            icon = CustomIcon(
                hub_image,
                icon_size=(10, 10)
            )
        marker=folium.Marker(
            location=[df.iloc[i]['lat'],df.iloc[i]['lng']],
            icon=icon,
            popup=str(df.iloc[i]['ID']),
            tooltip=name
        )
        m.add_child(marker)

# %% [markdown]
# ### Visualize the initial &final location

# %%
def coord_list(df):
    ## transform df with 'lat' and 'lng' to location list
    data=[]
    for i in range(len(df)):
        lats=df.iloc[i]['lat']
        lons=df.iloc[i]['lng']
        coor=[lats,lons]
        data.append(coor)

    return data

# %%
def cal_radius(nums):
    ## nums: input number to decide the radius
    radius_breaks=[0,10,100,1000,10000,100000,1000000]
    radius_stops=np.linspace(2,10,num=7)
    radius=0
    for i in range(len(radius_breaks)):
        
        if nums<radius_breaks[0]:
            radius=radius_stops[0]
            break
        if nums>=radius_breaks[i]:
            radius=radius_stops[i]


    return radius

# %%
def add_circle_markergroup(df,name,r_measure,col,m):
    ## df: with columns['ID','lat','lng']
    ## name: the name of the circle markergroup
    ## r_measure: the column used for measuring the radius of the circle
    ## col: the color of the circle
    ## m: base map
    circlemarker_group=folium.FeatureGroup(name=name)
    
    for i in range(len(df)):
        if r_measure=='':
            r=2
        else:
            r=cal_radius(df.iloc[i][r_measure])  

        folium.CircleMarker(
            location=[df.iloc[i]['lat'],df.iloc[i]['lng']],
            radius=r,
            color=col,
            stroke=False,
            fill=True,
            fill_opacity=1,
            opacity=1,
            popup=str(df.iloc[i]['ID']),
            tooltip=name
        ).add_to(circlemarker_group)
    circlemarker_group.add_to(m)

# %% [markdown]
# ### Visualize the deliver lane

# %%
import csv
from folium import plugins

# %%
loc_dic={}


for i in range(len(df_locations)):
    coordinate=[df_locations.iloc[i]['lat'],df_locations.iloc[i]['lng']]
    loc_dic.setdefault(str(df_locations.iloc[i]['ID']),coordinate)

# %%
n= pd.read_csv('result_n.csv', sep=":", header=0)

# %%
n
# Out:
#                                          Key  Lower  Value    Upper    Fixed  \
# 0                 ('F101', 'F101', 'i1', 0)       0    0.0    None    False
# 1                 ('F101', 'F101', 'i1', 1)       0    0.0    None    False
# 2                 ('F101', 'F101', 'i1', 2)       0    0.0    None    False
# 3                ('F101', 'F101', 'i10', 0)       0    0.0    None    False
# 4                ('F101', 'F101', 'i10', 1)       0    0.0    None    False
# 5                ('F101', 'F101', 'i10', 2)       0    0.0    None    False
# 6                ('F101', 'F101', 'i11', 0)       0    0.0    None    False
# 7                ('F101', 'F101', 'i11', 1)       0    0.0    None    False
# 8                ('F101', 'F101', 'i11', 2)       0    0.0    None    False
# 9                ('F101', 'F101', 'i12', 0)       0    0.0    None    False
# 10               ('F101', 'F101', 'i12', 1)       0    0.0    None    False
# 11               ('F101', 'F101', 'i12', 2)       0    0.0    None    False
# 12               ('F101', 'F101', 'i13', 0)       0    0.0    None    False
# 13               ('F101', 'F101', 'i13', 1)       0    0.0    None    False
# 14               ('F101', 'F101', 'i13', 2)       0    0.0    None    False
# 15               ('F101', 'F101', 'i14', 0)       0    0.0    None    False
# 16               ('F101', 'F101', 'i14', 1)       0    0.0    None    False
# 17               ('F101', 'F101', 'i14', 2)       0    0.0    None    False
# 18               ('F101', 'F101', 'i15', 0)       0    0.0    None    False
# 19               ('F101', 'F101', 'i15', 1)       0    0.0    None    False
# 20               ('F101', 'F101', 'i15', 2)       0    0.0    None    False
# 21               ('F101', 'F101', 'i16', 0)       0    0.0    None    False
# 22               ('F101', 'F101', 'i16', 1)       0    0.0    None    False
# 23               ('F101', 'F101', 'i16', 2)       0    0.0    None    False
# 24               ('F101', 'F101', 'i17', 0)       0    0.0    None    False
# 25               ('F101', 'F101', 'i17', 1)       0    0.0    None    False
# 26               ('F101', 'F101', 'i17', 2)       0    0.0    None    False
# 27               ('F101', 'F101', 'i18', 0)       0    0.0    None    False
# 28               ('F101', 'F101', 'i18', 1)       0    0.0    None    False
# 29               ('F101', 'F101', 'i18', 2)       0    0.0    None    False
# ...                                      ...    ...    ...      ...      ...
# 4054722               ('k9', 'k9', 'k7', 0)       0    0.0    None    False
# 4054723               ('k9', 'k9', 'k7', 1)       0    0.0    None    False
# 4054724               ('k9', 'k9', 'k7', 2)       0    0.0    None    False
# 4054725              ('k9', 'k9', 'k70', 0)       0    0.0    None    False
# 4054726              ('k9', 'k9', 'k70', 1)       0    0.0    None    False
# 4054727              ('k9', 'k9', 'k70', 2)       0    0.0    None    False
# 4054728              ('k9', 'k9', 'k71', 0)       0    0.0    None    False
# 4054729              ('k9', 'k9', 'k71', 1)       0    0.0    None    False
# 4054730              ('k9', 'k9', 'k71', 2)       0    0.0    None    False
# 4054731              ('k9', 'k9', 'k72', 0)       0    0.0    None    False
# 4054732              ('k9', 'k9', 'k72', 1)       0    0.0    None    False
# 4054733              ('k9', 'k9', 'k72', 2)       0    0.0    None    False
# 4054734              ('k9', 'k9', 'k73', 0)       0    0.0    None    False
# 4054735              ('k9', 'k9', 'k73', 1)       0    0.0    None    False
# 4054736              ('k9', 'k9', 'k73', 2)       0    0.0    None    False
# 4054737              ('k9', 'k9', 'k74', 0)       0    0.0    None    False
# 4054738              ('k9', 'k9', 'k74', 1)       0    0.0    None    False
# 4054739              ('k9', 'k9', 'k74', 2)       0    0.0    None    False
# 4054740              ('k9', 'k9', 'k75', 0)       0    0.0    None    False
# 4054741              ('k9', 'k9', 'k75', 1)       0    0.0    None    False
# 4054742              ('k9', 'k9', 'k75', 2)       0    0.0    None    False
# 4054743              ('k9', 'k9', 'k76', 0)       0    0.0    None    False
# 4054744              ('k9', 'k9', 'k76', 1)       0    0.0    None    False
# 4054745              ('k9', 'k9', 'k76', 2)       0    0.0    None    False
# 4054746               ('k9', 'k9', 'k8', 0)       0    0.0    None    False
# 4054747               ('k9', 'k9', 'k8', 1)       0    0.0    None    False
# 4054748               ('k9', 'k9', 'k8', 2)       0    0.0    None    False
# 4054749               ('k9', 'k9', 'k9', 0)       0    0.0    None    False
# 4054750               ('k9', 'k9', 'k9', 1)       0    0.0    None    False
# 4054751               ('k9', 'k9', 'k9', 2)       0    0.0    None    False
#
#            Stale             Domain
# 0         False    NonNegativeReals
# 1         False    NonNegativeReals
# 2         False    NonNegativeReals
# 3         False    NonNegativeReals
# 4         False    NonNegativeReals
# 5         False    NonNegativeReals
# 6         False    NonNegativeReals
# 7         False    NonNegativeReals
# 8         False    NonNegativeReals
# 9         False    NonNegativeReals
# 10        False    NonNegativeReals
# 11        False    NonNegativeReals
# 12        False    NonNegativeReals
# 13        False    NonNegativeReals
# 14        False    NonNegativeReals
# 15        False    NonNegativeReals
# 16        False    NonNegativeReals
# 17        False    NonNegativeReals
# 18        False    NonNegativeReals
# 19        False    NonNegativeReals
# 20        False    NonNegativeReals
# 21        False    NonNegativeReals
# 22        False    NonNegativeReals
# 23        False    NonNegativeReals
# 24        False    NonNegativeReals
# 25        False    NonNegativeReals
# 26        False    NonNegativeReals
# 27        False    NonNegativeReals
# 28        False    NonNegativeReals
# 29        False    NonNegativeReals
# ...          ...                ...
# 4054722   False    NonNegativeReals
# 4054723   False    NonNegativeReals
# 4054724   False    NonNegativeReals
# 4054725   False    NonNegativeReals
# 4054726   False    NonNegativeReals
# 4054727   False    NonNegativeReals
# 4054728   False    NonNegativeReals
# 4054729   False    NonNegativeReals
# 4054730   False    NonNegativeReals
# 4054731   False    NonNegativeReals
# 4054732   False    NonNegativeReals
# 4054733   False    NonNegativeReals
# 4054734   False    NonNegativeReals
# 4054735   False    NonNegativeReals
# 4054736   False    NonNegativeReals
# 4054737   False    NonNegativeReals
# 4054738   False    NonNegativeReals
# 4054739   False    NonNegativeReals
# 4054740   False    NonNegativeReals
# 4054741   False    NonNegativeReals
# 4054742   False    NonNegativeReals
# 4054743   False    NonNegativeReals
# 4054744   False    NonNegativeReals
# 4054745   False    NonNegativeReals
# 4054746   False    NonNegativeReals
# 4054747   False    NonNegativeReals
# 4054748   False    NonNegativeReals
# 4054749   False    NonNegativeReals
# 4054750   False    NonNegativeReals
# 4054751   False    NonNegativeReals
#
# [4054752 rows x 7 columns]

# %%
deliver_p=pd.DataFrame()
ini=[]
nextloc=[]
hop=[]
final=[]
package=[]

for i in range(0,len(n)):
    if n.iloc[i]['Value']!=0:
        k=n.iloc[i]['Key'].replace(' ','').replace('(','').replace(')','')
        l=list(k.split(','))
        ini.append(l[0])
        nextloc.append(l[1])
        final.append(l[2])
        hop.append(l[3])
        package.append(n.iloc[i]['Value'])

# %%
result_df=pd.DataFrame()
result_df['origin']=ini
result_df['next']=nextloc
result_df['hop']=hop
result_df['final']=final
result_df['packages']=package

# %%
# result_df=pd.DataFrame()
# result_df['origin']=n['start']
# result_df['next']=n['next']
# result_df['final']=n['Client']
# result_df['hop']=n['hops']
# result_df['packages']=n['Packages']

# %%
result_df
# Out:
#      origin    next hop  final  packages
# 0    'F106'  'F110'   1   'k1'       3.0
# 1    'F106'  'F110'   1  'k24'       1.0
# 2    'F106'  'F110'   1  'k26'       1.0
# 3    'F106'  'F110'   1  'k38'       1.0
# 4    'F106'  'F110'   1  'k44'       1.0
# 5    'F106'  'F110'   1  'k56'       1.0
# 6    'F106'  'F110'   1   'k7'       1.0
# 7    'F106'  'F110'   1  'k75'       1.0
# 8    'F106'  'F110'   1   'k8'       1.0
# 9    'F106'   'k57'   2  'k57'       1.0
# 10   'F106'   'k62'   2  'k62'       1.0
# 11   'F106'   'k73'   1  'k73'       1.0
# 12   'F106'   'k73'   2  'k73'       1.0
# 13   'F108'   'k13'   1  'k13'       4.0
# 14   'F108'   'k13'   2  'k13'       1.0
# 15   'F108'   'k14'   1  'k14'      11.0
# 16   'F108'   'k14'   2  'k14'       2.0
# 17   'F108'    'k3'   1   'k3'       6.0
# 18   'F108'   'k41'   1  'k41'       5.0
# 19   'F108'   'k42'   1  'k42'       1.0
# 20   'F108'   'k43'   1  'k43'       2.0
# 21   'F108'   'k44'   1  'k44'       3.0
# 22   'F108'   'k44'   2  'k44'       1.0
# 23   'F108'   'k45'   1  'k45'       4.0
# 24   'F108'   'k45'   2  'k45'       1.0
# 25   'F108'   'k46'   1  'k46'       6.0
# 26   'F108'   'k47'   1  'k47'       2.0
# 27   'F108'   'k47'   2  'k47'       1.0
# 28   'F108'   'k48'   1  'k48'       5.0
# 29   'F108'    'k5'   1   'k5'       5.0
# ..      ...     ...  ..    ...       ...
# 302    'i8'  'F110'   2  'k10'       1.0
# 303    'i8'  'F110'   2  'k16'       2.0
# 304    'i8'  'F110'   2  'k18'       2.0
# 305    'i8'  'F110'   2  'k20'       1.0
# 306    'i8'  'F110'   2  'k23'       7.0
# 307    'i8'  'F110'   2  'k24'       1.0
# 308    'i8'  'F110'   2  'k26'       1.0
# 309    'i8'  'F110'   2  'k27'       1.0
# 310    'i8'  'F110'   2  'k30'       1.0
# 311    'i8'  'F110'   2  'k32'       3.0
# 312    'i8'  'F110'   2  'k34'       1.0
# 313    'i8'  'F110'   2  'k37'       1.0
# 314    'i8'  'F110'   2  'k38'       1.0
# 315    'i8'  'F110'   2  'k39'       2.0
# 316    'i8'  'F110'   2  'k51'       1.0
# 317    'i8'  'F110'   2  'k52'       1.0
# 318    'i8'  'F110'   2  'k58'       1.0
# 319    'i8'  'F110'   2  'k59'       1.0
# 320    'i8'  'F110'   2   'k6'       1.0
# 321    'i8'  'F110'   2  'k61'       1.0
# 322    'i8'  'F110'   2  'k63'       2.0
# 323    'i9'  'F110'   2  'k10'       1.0
# 324    'i9'  'F110'   2  'k12'       2.0
# 325    'i9'  'F110'   2  'k17'       1.0
# 326    'i9'  'F110'   2  'k38'       1.0
# 327    'i9'  'F110'   2   'k4'      17.0
# 328    'i9'  'F110'   2  'k40'       1.0
# 329    'i9'  'F110'   2  'k47'       1.0
# 330    'i9'  'F110'   2  'k55'       1.0
# 331    'i9'  'F110'   2  'k72'       2.0
#
# [332 rows x 5 columns]

# %%
result_df.to_csv("result_process.csv")

# %%
def cal_lanewo(nums):
    ## nums: input number to decide the weights
    weight_breaks=[1,10,100,1000,10000,100000,1000000,10000000]
    weight_stops=np.linspace(1,5,num=8)
    opacity_stops=np.linspace(0.2,1,num=8)
    for i in range(len(weight_breaks)):
        if nums<weight_breaks[0]:
            weight=weight_stops[0]
            opacity=opacity_stops[0]
            break
        if nums>=weight_breaks[i]:
            weight=weight_stops[i]
            opacity=opacity_stops[i]

    return weight,opacity

# %%
# def add_lane_group(df,name,w_measure,col,m):
#     for i in range(len(df)):
#         start=str(df.iloc[i]['origin'])
#         end=str(df.iloc[i]['next'])
#         hops=df.iloc[i]['hop']
#         line=[]
#         line.append(loc_dic[start])
#         line.append(loc_dic[end])
#         if w_measure=='':
#             w=5
#             o=1
#         else:
#             w,o=cal_lanewo(df.iloc[i][w_measure])
#         folium.PolyLine(
#             locations=line,
#             weight=w,
#             color=col,
#             popup=str(df.iloc[i]['hop']),
#             opacity=o,
#             tooltip=name
#         ).add_to(m)

# %%
def add_lane_group(df,name,w_measure,col,m):
    for i in range(len(df)):
        start=df.iloc[i]['origin'].replace("'","")
        end=df.iloc[i]['next'].replace("'","")
        hops=df.iloc[i]['hop']
        line=[]
        line.append(loc_dic[start])
        line.append(loc_dic[end])
        if w_measure=='':
            w=5
            o=1
        else:
            w,o=cal_lanewo(df.iloc[i][w_measure])
        attr = {'fill': '#2166ac','fond-size':'1'}
        p=folium.PolyLine(
            locations=line,
            weight=w,
            color=col,
            popup=str(df.iloc[i]['hop']),
            opacity=o,
            tooltip=start+" "+end
        ).add_to(m)
        plugins.PolyLineTextPath(
            p,
            '\u2911',
            repeat=True,
            offset=0,
            attributes=attr
        ).add_to(m)

# %%
m1 = folium.Map(location=[41.9, -97.3],tiles="Mapbox Bright",zoom_start=4)

# %%
##add result lane
add_lane_group(result_df,'lane','packages','#4393c3',m1)
add_facility_marker(facility_df,'random facility',m1,finalhub)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[41.9, -97.3],tiles="Mapbox Bright",zoom_start=4)

# %%
# Add layer control and show map
add_circle_markergroup(Initial_df,'deliver ini','packages','#d95f0e',m)
add_circle_markergroup(Final_df,'deliver final','packages','#f4a582',m)
# add_circle_markergroup(delInitial_df,'return ini','packages','#4393c3',m)
# add_circle_markergroup(delFinal_df,'return final','packages','#2166ac',m)
add_facility_marker(facility_df,'random facility',m,finalhub)
folium.LayerControl(collapsed=False).add_to(m)
# m = folium.Map(location=[np.mean(df_locations['lat']), np.mean(df_locations['lng'])],tiles="Mapbox Bright",zoom_start=4)
# Out:
# 2.0

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3= folium.Map(location=[41.9, -97.3],tiles="Mapbox Bright",zoom_start=4)

# %%
##add result lane
add_lane_group(result_df,'lane','packages','#4393c3',m3)
add_facility_marker(facility_df,'random facility',m3,finalhub)

# %%
# Add layer control and show map
add_circle_markergroup(Initial_df,'deliver ini','packages','#d95f0e',m3)
add_circle_markergroup(Final_df,'deliver final','packages','#f4a582',m3)
# add_circle_markergroup(delInitial_df,'return ini','packages','#4393c3',m)
# add_circle_markergroup(delFinal_df,'return final','packages','#2166ac',m)
add_facility_marker(facility_df,'random facility',m3,finalhub)
folium.LayerControl(collapsed=False).add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
