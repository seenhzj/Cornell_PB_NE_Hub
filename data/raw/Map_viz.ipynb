# %% [markdown]
# ## Start

# %%
import pandas as pd
import numpy as np

# %%
user="cornell"
password="Pitney@1a"
host="gec-dwh.ctz5iw1v2fh7.us-west-2.rds.amazonaws.com"
db="cornell"

conn = f"mysql+pymysql://{user}:{password}@{host}/{db}"

# %%
from sqlalchemy import create_engine

engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{db}")

# %%
result = engine.execute('show tables in cornell')
for _r in result:
    print(_r)
# Out:
# ('deliver_package_info',)
# ('input_df',)
# ('ne_delivery_data_by_day_2018',)
# ('ne_returns_data_by_day_2018',)
# ('return_package_info',)
# ('return_package_info_update',)
# ('test_df',)

# %%
result = engine.execute('describe deliver_package_info ')
for _r in result:
    print(_r)
# Out:
# ('index', 'bigint(20)', 'YES', 'MUL', None, '')
# ('origindate', 'date', 'YES', '', None, '')
# ('originfacilityzip', 'text', 'YES', '', None, '')
# ('destinationfacilityzip', 'text', 'YES', '', None, '')
# ('count', 'bigint(20)', 'YES', '', None, '')
# ('origin_zip3', 'text', 'YES', '', None, '')
# ('origin_state', 'text', 'YES', '', None, '')
# ('origin_lat', 'text', 'YES', '', None, '')
# ('origin_lng', 'text', 'YES', '', None, '')
# ('dest_zip3', 'text', 'YES', '', None, '')
# ('dest_state', 'text', 'YES', '', None, '')
# ('dest_lat', 'text', 'YES', '', None, '')
# ('dest_lng', 'text', 'YES', '', None, '')

# %%
result = engine.execute('select origindate,originfacilityzip,destinationfacilityzip,count from deliver_package_info')
deliver_df = pd.DataFrame(result.fetchall(),columns=['origindate','originfacilityzip','destinationfacilityzip','count'])

# %% [markdown]
# ## Visualization prepare

# %% [markdown]
# ### deliver

# %%
result = engine.execute('select origin_zip3,origin_state,origin_lat,origin_lng,sum(count) from deliver_package_info group by origin_zip3')
origin_df = pd.DataFrame(result.fetchall(),columns=['facilityzip','state','lat','lng','sum'])

# %%
for i in range(len(origin_df)):
    if origin_df['lat'][i]=='':
         origin_df = origin_df.drop(i)

# %%
origin_df['type']=1

# %%
origin_df
# Out:
#    facilityzip state               lat                lng       sum  type
# 0          060    CT   41.791323312423  -72.8538070382769    255588     1
# 1          064    CT  41.3447619004598   -73.068704647852    344266     1
# 2          070    NJ  40.5833124911422  -74.2703150322948      9626     1
# 3          072    NJ  40.6705538121771   -74.177558305216      9259     1
# 4          079    NJ  40.7149350827677  -74.3650397802954     19195     1
# 5          088    NJ  40.6240218011197  -74.8843774239638    963698     1
# 6          100    NY  40.7505956027072  -73.9969904238369     11850     1
# 7          105    NY  41.2922361699564  -73.7604420299132     21597     1
# 8          109    NY  41.1434616274125  -74.1238460876456     45827     1
# 9          110    NY  40.7220752067917  -73.7068341419121   7014974     1
# 10         111    NY  40.7458765271783  -73.9401086213694   2739005     1
# 11         114    NY  40.7049329101236  -73.7938723442845    244942     1
# 12         115    NY  40.7467145052922  -73.6395425596232      2164     1
# 13         151    PA  40.5804379499168  -79.9554146477495    181757     1
# 14         163    PA  41.4542864255809  -79.6519755218344   2299856     1
# 15         170    PA  40.5266561258918  -77.8269602130124   1856633     1
# 16         180    PA  40.4692977017575  -75.6482993536905      2468     1
# 17         190    PA  40.1269047717822  -75.1256831129385      3669     1
# 18         196    PA  40.3531759321287  -75.9404565195716    344850     1
# 19         197    DE  39.5851778604444  -75.6993444178467     16326     1
# 20         210    MD  39.4748982668505  -76.2084143365847      2974     1
# 21         211    MD  39.6865546812135  -76.8461063568031     19583     1
# 22         216    MD   38.795345473114  -76.0826444285563    956108     1
# 23         303    GA  33.7554224110405  -84.3904423185221   7793993     1
# 24         430    OH  40.0879778724422  -82.6129450831437  17920618     1
# 25         460    IN  40.2490326631515  -85.6604766032736  18825162     1
# 26         461    IN  39.9957985443484  -86.6207323444806         9     1
# 27         787    TX  30.2706053511004  -97.7433982939145        59     1

# %%
result = engine.execute('select dest_zip3,dest_state,dest_lat,dest_lng,sum(count) from deliver_package_info group by dest_zip3')
dest_df = pd.DataFrame(result.fetchall(),columns=['facilityzip','state','lat','lng','sum'])

# %%
for i in range(len(dest_df)):
    if dest_df['lat'][i]=='':
        dest_df = dest_df.drop(i)

# %%
dest_df['type']=2
dest_df
# Out:
#    facilityzip state               lat                lng       sum  type
# 1          011    MA  42.1056970748294  -72.5980788159072     42709     2
# 2          015    MA  42.1968723825208  -71.8453871667191     61402     2
# 3          018    MA   42.485950411217  -71.1553696696814     14232     2
# 4          022    MA  42.3582224850777  -71.0584272136915       599     2
# 5          023    MA   42.077750776689  -71.0424176095744      4889     2
# 6          027    MA   41.784464601322  -71.0607687937182   1298656     2
# 7          029    RI  41.8258558538419  -71.4134288124013     68602     2
# 8          031    NH  42.9885494067885  -71.4658168318337    253112     2
# 9          038    NH  43.0727535404586  -70.8040595470843     43716     2
# 10         040    ME   43.530478933588  -70.9212281508382    221787     2
# 11         044    ME  44.8496480032224  -68.8459384951881     16460     2
# 12         050    VT  43.6747130026572  -72.3860024850608    110823     2
# 13         061    CT  41.7665105110331  -72.6739123853212     69858     2
# 14         064    CT  41.3447619004598   -73.068704647852    730800     2
# 15         070    NJ  40.5833124911422  -74.2703150322948   3683771     2
# 16         072    NJ  40.6705538121771   -74.177558305216    426928     2
# 17         076    NJ  40.8890286852354  -74.0457692553894      2753     2
# 18         080    NJ  39.5518083812818  -75.3523123924866     13775     2
# 19         081    NJ  39.9460607680924   -75.121656324572     47604     2
# 20         086    NJ  40.2200553459778  -74.7606863536026      9145     2
# 21         115    NY  40.7467145052922  -73.6395425596232       137     2
# 22         117    NY  40.6819634281226  -73.4125545304573     43930     2
# 23         122    NY  42.6472800295118  -73.7516930834563    320510     2
# 24         125    NY  41.8598590951481  -73.5602758628509     59598     2
# 25         132    NY  43.0435782151902  -76.1507035299336    350806     2
# 26         137    NY  42.2343589257587  -75.5390075382465     47852     2
# 27         142    NY  42.8965886623808  -78.8865218406153    304888     2
# 28         146    NY  43.1591428523363  -77.6068194844908    259811     2
# 29         150    PA  40.5931045064299  -80.3210143620504     94806     2
# 30         151    PA  40.5804379499168  -79.9554146477495      6572     2
# 31         152    PA         40.473674         -79.955872    196404     2
# 32         163    PA  41.4542864255809  -79.6519755218344     35833     2
# 33         171    PA  40.2595772715771  -76.8875671218581    459801     2
# 34         176    PA  40.0730558106315  -76.3141886839793     49699     2
# 35         180    PA  40.4692977017575  -75.6482993536905     72225     2
# 36         190    PA  40.1269047717822  -75.1256831129385   2102056     2
# 37         191    PA  39.9526139495128   -75.183696779919      2047     2
# 38         197    DE  39.5851778604444  -75.6993444178467     13207     2
# 39         207    MD  39.1250801086426  -76.8025207519531     34933     2
# 40         210    MD  39.4748982668505  -76.2084143365847   1832008     2
# 41         212    MD  39.2939663221704  -76.6223873270678     75966     2
# 42         216    MD   38.795345473114  -76.0826444285563     20794     2
# 43         231    VA  37.7104569783371  -77.8364615182062    156771     2
# 44         232    VA  37.5392326292499  -77.4374487131616    288657     2
# 45         233    VA  37.2548440359096  -75.7987198574783    259214     2
# 46         235    VA  36.8517460063432  -76.2800020807876     17274     2
# 47         240    VA  37.2706334855373  -79.9411734251418    233730     2
# 48         250    WV   38.251464922047   -81.771408820272     35086     2
# 49         253    WV  38.3510365905497  -81.6282391249495     73883     2
# 50         303    GA  33.7554224110405  -84.3904423185221  18221341     2
# 51         376    TN             36.33             -82.34       505     2
# 52         460    IN  40.2490326631515  -85.6604766032736  27928393     2

# %%
deliver_df=origin_df.append(dest_df)

# %%
deliver_df['lng']=deliver_df['lng'].astype(float)
deliver_df['lat']=deliver_df['lat'].astype(float)

# %% [markdown]
# ### return

# %%
result = engine.execute('select origin_zip3,origin_state,origin_lat,origin_lng,sum(count) from return_package_info group by origin_zip3')
return_origin_df = pd.DataFrame(result.fetchall(),columns=['facilityzip','state','lat','lng','sum'])

# %%
for i in range(len(return_origin_df)):
    if return_origin_df['lat'][i]=='':
        return_origin_df = return_origin_df.drop(i)

# %%
return_origin_df['type']=3

# %%
return_origin_df
# Out:
#     facilityzip state               lat                lng       sum  type
# 2           011    MA  42.1056970748294  -72.5980788159072      1095     3
# 3           012    MA  42.4604768859696  -73.2799065895365        69     3
# 4           013    MA  42.6271204390973  -72.6052347738515         2     3
# 5           014    MA  42.5853946189292  -71.8170603313981       214     3
# 6           015    MA  42.1968723825208  -71.8453871667191     45529     3
# 7           017    MA  42.3216788633089  -71.4381268836105      4681     3
# 8           018    MA   42.485950411217  -71.1553696696814     41366     3
# 9           020    MA  42.0776195305726  -71.4741105603547       400     3
# 10          021    MA  42.3591461181641  -71.0582618713379       995     3
# 11          022    MA  42.3582224850777  -71.0584272136915    119285     3
# 12          023    MA   42.077750776689  -71.0424176095744     22549     3
# 13          025    MA  41.7453608223818  -70.5898646522039        12     3
# 14          027    MA   41.784464601322  -71.0607687937182    599439     3
# 15          028    RI  41.9531504079649  -71.4575637476118        60     3
# 16          029    RI  41.8258558538419  -71.4134288124013     97282     3
# 17          030    NH  42.8706400439212  -71.6071227268889         3     3
# 18          031    NH  42.9885494067885  -71.4658168318337    143438     3
# 19          032    NH   43.973130815468   -71.497906160348         6     3
# 20          034    NH  42.9668030237277  -72.2966382515709         1     3
# 21          038    NH  43.0727535404586  -70.8040595470843     22583     3
# 22          040    ME   43.530478933588  -70.9212281508382     88733     3
# 23          043    ME  44.3646757311266  -69.7369123220753         2     3
# 24          044    ME  44.8496480032224  -68.8459384951881     28951     3
# 25          045    ME   43.893249051325  -69.8307580002148        16     3
# 26          046    ME   44.672309805652  -68.4163627150221         1     3
# 27          047    ME  46.2244491577148  -68.0458221435547         1     3
# 28          050    VT  43.6747130026572  -72.3860024850608     46737     3
# 29          051    VT  43.1803170078988  -72.4961172508692         1     3
# 30          054    VT  44.4737663776314  -73.2228904778506     33709     3
# 31          057    VT  43.6333772575043  -72.9169784379936        65     3
# ..          ...   ...               ...                ...       ...   ...
# 134         222    VA  38.8864730869865   -77.095282559385       765     3
# 135         223    VA  38.8199755074821   -77.059308330927       336     3
# 136         224    VA  38.2964852824198  -77.4825984893031       153     3
# 137         225    VA  37.7528281164671  -76.5133422733761         2     3
# 138         227    VA  38.4381132558566  -77.9980224567107       224     3
# 139         228    VA  38.4036477843555  -78.8757027983826      1418     3
# 140         229    VA   38.088397042988   -78.555480911151       246     3
# 141         230    VA  37.3507955981197  -77.9612614629298        71     3
# 142         231    VA  37.7104569783371  -77.8364615182062    181718     3
# 143         232    VA  37.5392326292499  -77.4374487131616     82383     3
# 144         233    VA  37.2548440359096  -75.7987198574783     94060     3
# 145         234    VA  37.3818626403809  -75.7334594726563         5     3
# 146         235    VA  36.8517460063432  -76.2800020807876     39138     3
# 147         236    VA  37.0458849267273  -76.4679680206234      4319     3
# 148         238    VA  37.2378270001316  -77.3361824196274      1327     3
# 149         240    VA  37.2706334855373  -79.9411734251418     66795     3
# 150         241    VA  37.1776874595886  -79.8012013665201         1     3
# 151         243    VA  37.0629350128409  -80.7944718470008         8     3
# 152         244    VA  38.1313100222885  -79.0886474489815         7     3
# 153         245    VA  37.3582193349599  -79.1458222743395       876     3
# 154         247    WV   37.301097505709   -81.219490448085         4     3
# 155         250    WV   38.251464922047   -81.771408820272      8717     3
# 156         252    WV  38.3180111115549  -81.8557992355087         4     3
# 157         253    WV  38.3510365905497  -81.6282391249495    121721     3
# 158         254    WV  39.4568580833694  -77.9720334526476         4     3
# 159         260    WV  40.0699778498526   -80.650842414691        15     3
# 160         261    WV  39.2389668738894  -81.5758851948238         3     3
# 161         263    WV        39.2809995        -80.3123345        11     3
# 162         303    GA  33.7554224110405  -84.3904423185221   9068935     3
# 163         460    IN  40.2490326631515  -85.6604766032736  13926225     3
#
# [162 rows x 6 columns]

# %%
result = engine.execute('select dest_zip3,dest_state,dest_lat,dest_lng,sum(count) from return_package_info group by dest_zip3')
return_dest_df = pd.DataFrame(result.fetchall(),columns=['facilityzip','state','lat','lng','sum'])

# %%
for i in range(len(return_dest_df)):
    if return_dest_df['lat'][i]=='':
        return_dest_df = return_dest_df.drop(i)

# %%
return_dest_df['type']=4
return_dest_df
# Out:
#    facilityzip state               lat                lng      sum  type
# 0          014    MA  42.5853946189292  -71.8170603313981    17934     4
# 1          021    MA  42.3591461181641  -71.0582618713379        5     4
# 2          023    MA   42.077750776689  -71.0424176095744      329     4
# 3          030    NH  42.8706400439212  -71.6071227268889    10851     4
# 4          032    NH   43.973130815468   -71.497906160348        2     4
# 5          060    CT   41.791323312423  -72.8538070382769       93     4
# 6          064    CT  41.3447619004598   -73.068704647852        2     4
# 7          070    NJ  40.5833124911422  -74.2703150322948   196060     4
# 8          074    NJ  41.0331440150586  -74.1332355995617     1068     4
# 9          078    NJ  40.9151229858398  -74.5807952880859     1794     4
# 10         079    NJ  40.7149350827677  -74.3650397802954        1     4
# 11         088    NJ  40.6240218011197  -74.8843774239638   470062     4
# 12         100    NY  40.7505956027072  -73.9969904238369       30     4
# 13         110    NY  40.7220752067917  -73.7068341419121   218401     4
# 14         111    NY  40.7458765271783  -73.9401086213694     3716     4
# 15         112    NY  40.6970240928097  -73.9890018436833        1     4
# 16         114    NY  40.7049329101236  -73.7938723442845   280495     4
# 17         115    NY  40.7467145052922  -73.6395425596232      725     4
# 18         142    NY  42.8965886623808  -78.8865218406153     2867     4
# 19         145    NY  43.0974835325808  -77.3380411445769       23     4
# 20         156    PA  40.3162370614182  -79.5350161954073     6824     4
# 21         163    PA  41.4542864255809  -79.6519755218344  1253021     4
# 22         170    PA  40.5266561258918  -77.8269602130124  2261226     4
# 23         174    PA  39.9589519819136  -76.7338584141311      446     4
# 24         175    PA  40.1567631818116  -76.2045168810913   694270     4
# 25         176    PA  40.0730558106315  -76.3141886839793  7002847     4
# 26         180    PA  40.4692977017575  -75.6482993536905    15875     4
# 27         181    PA  40.6032267522707  -75.4696989223711     4156     4
# 28         186    PA  41.1823690190279  -75.7524397228504   506926     4
# 29         187    PA  41.2433794220387   -75.885391254118      526     4
# 30         190    PA  40.1269047717822  -75.1256831129385       25     4
# 31         194    PA  40.1300633912866  -75.3315801129381       13     4
# 32         207    MD  39.1250801086426  -76.8025207519531      172     4
# 33         210    MD  39.4748982668505  -76.2084143365847     2149     4
# 34         211    MD  39.6865546812135  -76.8461063568031   148217     4
# 35         217    MD  39.4477721717067  -77.3342903346635    48582     4
# 36         218    MD  38.3759221931837   -75.643197513886     4427     4
# 37         232    VA  37.5392326292499  -77.4374487131616     2604     4
# 38         245    VA  37.3582193349599  -79.1458222743395        3     4
# 39         278    NC   35.911301017443  -77.7362497363615  2739418     4
# 40         303    GA  33.7554224110405  -84.3904423185221  4029467     4
# 41         460    IN  40.2490326631515  -85.6604766032736  7722785     4
# 42         524    IA  41.9754515759122  -91.6587232808614  2304496     4
# 43         750    TX  32.9602558381961  -96.8380888773413   961398     4
# 44         761    TX   32.745762503794  -97.3281747471537  1636282     4
# 45         924    CA  34.0974426269531  -117.292900085449   541438     4
# 46         925    CA  33.9962289444077  -117.372113197087    93646     4
# 47         930    CA  34.3729934692383  -119.306915283203    90916     4

# %%
return_df=return_origin_df.append(return_dest_df)

# %%
return_df['lng']=return_df['lng'].astype(float)
return_df['lat']=return_df['lat'].astype(float)
return_df
# Out:
#    facilityzip state        lat         lng      sum  type
# 2          011    MA  42.105697  -72.598079     1095     3
# 3          012    MA  42.460477  -73.279907       69     3
# 4          013    MA  42.627120  -72.605235        2     3
# 5          014    MA  42.585395  -71.817060      214     3
# 6          015    MA  42.196872  -71.845387    45529     3
# 7          017    MA  42.321679  -71.438127     4681     3
# 8          018    MA  42.485950  -71.155370    41366     3
# 9          020    MA  42.077620  -71.474111      400     3
# 10         021    MA  42.359146  -71.058262      995     3
# 11         022    MA  42.358222  -71.058427   119285     3
# 12         023    MA  42.077751  -71.042418    22549     3
# 13         025    MA  41.745361  -70.589865       12     3
# 14         027    MA  41.784465  -71.060769   599439     3
# 15         028    RI  41.953150  -71.457564       60     3
# 16         029    RI  41.825856  -71.413429    97282     3
# 17         030    NH  42.870640  -71.607123        3     3
# 18         031    NH  42.988549  -71.465817   143438     3
# 19         032    NH  43.973131  -71.497906        6     3
# 20         034    NH  42.966803  -72.296638        1     3
# 21         038    NH  43.072754  -70.804060    22583     3
# 22         040    ME  43.530479  -70.921228    88733     3
# 23         043    ME  44.364676  -69.736912        2     3
# 24         044    ME  44.849648  -68.845938    28951     3
# 25         045    ME  43.893249  -69.830758       16     3
# 26         046    ME  44.672310  -68.416363        1     3
# 27         047    ME  46.224449  -68.045822        1     3
# 28         050    VT  43.674713  -72.386002    46737     3
# 29         051    VT  43.180317  -72.496117        1     3
# 30         054    VT  44.473766  -73.222890    33709     3
# 31         057    VT  43.633377  -72.916978       65     3
# ..         ...   ...        ...         ...      ...   ...
# 18         142    NY  42.896589  -78.886522     2867     4
# 19         145    NY  43.097484  -77.338041       23     4
# 20         156    PA  40.316237  -79.535016     6824     4
# 21         163    PA  41.454286  -79.651976  1253021     4
# 22         170    PA  40.526656  -77.826960  2261226     4
# 23         174    PA  39.958952  -76.733858      446     4
# 24         175    PA  40.156763  -76.204517   694270     4
# 25         176    PA  40.073056  -76.314189  7002847     4
# 26         180    PA  40.469298  -75.648299    15875     4
# 27         181    PA  40.603227  -75.469699     4156     4
# 28         186    PA  41.182369  -75.752440   506926     4
# 29         187    PA  41.243379  -75.885391      526     4
# 30         190    PA  40.126905  -75.125683       25     4
# 31         194    PA  40.130063  -75.331580       13     4
# 32         207    MD  39.125080  -76.802521      172     4
# 33         210    MD  39.474898  -76.208414     2149     4
# 34         211    MD  39.686555  -76.846106   148217     4
# 35         217    MD  39.447772  -77.334290    48582     4
# 36         218    MD  38.375922  -75.643198     4427     4
# 37         232    VA  37.539233  -77.437449     2604     4
# 38         245    VA  37.358219  -79.145822        3     4
# 39         278    NC  35.911301  -77.736250  2739418     4
# 40         303    GA  33.755422  -84.390442  4029467     4
# 41         460    IN  40.249033  -85.660477  7722785     4
# 42         524    IA  41.975452  -91.658723  2304496     4
# 43         750    TX  32.960256  -96.838089   961398     4
# 44         761    TX  32.745763  -97.328175  1636282     4
# 45         924    CA  34.097443 -117.292900   541438     4
# 46         925    CA  33.996229 -117.372113    93646     4
# 47         930    CA  34.372993 -119.306915    90916     4
#
# [210 rows x 6 columns]

# %% [markdown]
# ## Mapbox GL

# %% [markdown]
# ### deliver-viz

# %%
#!pip install mapboxgl

# %%
import os

import pandas as pd

from mapboxgl.utils import *
from mapboxgl.viz import *
# Must be a public token, starting with `pk`
token="pk.eyJ1IjoiaXJpc3pvdSIsImEiOiJjanMzazJ6ODgyZ2VxM3lubTkwYTBmb2Y0In0._3qEqCr8-IXLuBlQJrCAXg"

# %%
# Create a geojson file export from a Pandas dataframe
df_to_geojson(deliver_df, filename='deliver_points.geojson',
              properties=['facilityzip','state','sum','type'],lat='lat', lon='lng', precision=3)
# Out:
# {'type': 'file', 'filename': 'deliver_points.geojson', 'feature_count': 80}

# %%
# Generate color stops from colorBrewer
color_breaks = [0,1,2,3,4,5]
color_stops = create_color_stops(color_breaks, colors='YlGnBu')

# Generate radius breaks from data domain and circle-radius range
measure_radius = 'sum'
radius_breaks = [0,10,100,1000,10000,100000,1000000,10000000,100000000,1000000000]
radius_stops = create_radius_stops(radius_breaks, 2, 10)

# %%
# Create the viz
deliver_viz = GraduatedCircleViz('deliver_points.geojson',
                          access_token=token,
                          color_default='#8fb2ea',
                          color_property='type',
                          color_stops=color_stops,
                          radius_property='sum',
                          stroke_color='black',
                          stroke_width=0.5,
                          radius_stops=radius_stops,
                          center=(-95, 40),
                          zoom=3,
                          below_layer='waterway-label')
deliver_viz.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid black 0.5px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRig

# %% [markdown]
# ### return- viz

# %%
df_to_geojson(return_df, filename='return_points.geojson',
              properties=['facilityzip','state','sum','type']
              ,lat='lat', lon='lng', precision=3)
# Out:
# {'type': 'file', 'filename': 'return_points.geojson', 'feature_count': 210}

# %%
# Generate color stops from colorBrewer
measure_color = 'originfacilityzip'
color_breaks = [0,1,2,3,4,5]
color_stops = create_color_stops(color_breaks, colors='YlGnBu')

# Generate radius breaks from data domain and circle-radius range
measure_radius = 'sum'
radius_breaks = [0,10,100,1000,10000,100000,1000000,10000000,100000000,1000000000]
radius_stops = create_radius_stops(radius_breaks, 2, 10)

# %%
# Create the viz
return_viz = GraduatedCircleViz('return_points.geojson',
                          access_token=token,
                          color_property='type',
                          color_stops=color_stops,
                          radius_property='sum',
                          stroke_color='black',
                          stroke_width=0.5,
                          radius_stops=radius_stops,
                          center=(-95, 40),
                          zoom=3,
                          below_layer='waterway-label')
return_viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid black 0.5px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRig

# %% [markdown]
# ### All

# %%
df=deliver_df.append(return_df)

# %%
df
# Out:
#    facilityzip state        lat         lng       sum  type
# 0          060    CT  41.791323  -72.853807    255588     1
# 1          064    CT  41.344762  -73.068705    344266     1
# 2          070    NJ  40.583312  -74.270315      9626     1
# 3          072    NJ  40.670554  -74.177558      9259     1
# 4          079    NJ  40.714935  -74.365040     19195     1
# 5          088    NJ  40.624022  -74.884377    963698     1
# 6          100    NY  40.750596  -73.996990     11850     1
# 7          105    NY  41.292236  -73.760442     21597     1
# 8          109    NY  41.143462  -74.123846     45827     1
# 9          110    NY  40.722075  -73.706834   7014974     1
# 10         111    NY  40.745877  -73.940109   2739005     1
# 11         114    NY  40.704933  -73.793872    244942     1
# 12         115    NY  40.746715  -73.639543      2164     1
# 13         151    PA  40.580438  -79.955415    181757     1
# 14         163    PA  41.454286  -79.651976   2299856     1
# 15         170    PA  40.526656  -77.826960   1856633     1
# 16         180    PA  40.469298  -75.648299      2468     1
# 17         190    PA  40.126905  -75.125683      3669     1
# 18         196    PA  40.353176  -75.940457    344850     1
# 19         197    DE  39.585178  -75.699344     16326     1
# 20         210    MD  39.474898  -76.208414      2974     1
# 21         211    MD  39.686555  -76.846106     19583     1
# 22         216    MD  38.795345  -76.082644    956108     1
# 23         303    GA  33.755422  -84.390442   7793993     1
# 24         430    OH  40.087978  -82.612945  17920618     1
# 25         460    IN  40.249033  -85.660477  18825162     1
# 26         461    IN  39.995799  -86.620732         9     1
# 27         787    TX  30.270605  -97.743398        59     1
# 1          011    MA  42.105697  -72.598079     42709     2
# 2          015    MA  42.196872  -71.845387     61402     2
# ..         ...   ...        ...         ...       ...   ...
# 18         142    NY  42.896589  -78.886522      2867     4
# 19         145    NY  43.097484  -77.338041        23     4
# 20         156    PA  40.316237  -79.535016      6824     4
# 21         163    PA  41.454286  -79.651976   1253021     4
# 22         170    PA  40.526656  -77.826960   2261226     4
# 23         174    PA  39.958952  -76.733858       446     4
# 24         175    PA  40.156763  -76.204517    694270     4
# 25         176    PA  40.073056  -76.314189   7002847     4
# 26         180    PA  40.469298  -75.648299     15875     4
# 27         181    PA  40.603227  -75.469699      4156     4
# 28         186    PA  41.182369  -75.752440    506926     4
# 29         187    PA  41.243379  -75.885391       526     4
# 30         190    PA  40.126905  -75.125683        25     4
# 31         194    PA  40.130063  -75.331580        13     4
# 32         207    MD  39.125080  -76.802521       172     4
# 33         210    MD  39.474898  -76.208414      2149     4
# 34         211    MD  39.686555  -76.846106    148217     4
# 35         217    MD  39.447772  -77.334290     48582     4
# 36         218    MD  38.375922  -75.643198      4427     4
# 37         232    VA  37.539233  -77.437449      2604     4
# 38         245    VA  37.358219  -79.145822         3     4
# 39         278    NC  35.911301  -77.736250   2739418     4
# 40         303    GA  33.755422  -84.390442   4029467     4
# 41         460    IN  40.249033  -85.660477   7722785     4
# 42         524    IA  41.975452  -91.658723   2304496     4
# 43         750    TX  32.960256  -96.838089    961398     4
# 44         761    TX  32.745763  -97.328175   1636282     4
# 45         924    CA  34.097443 -117.292900    541438     4
# 46         925    CA  33.996229 -117.372113     93646     4
# 47         930    CA  34.372993 -119.306915     90916     4
#
# [290 rows x 6 columns]

# %%
df_to_geojson(df, filename='PB_points.geojson',
              properties=['facilityzip','major_city','sum','type']
              ,lat='lat', lon='lng', precision=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-c08418d231ac> in <module>
#       1 df_to_geojson(df, filename='PB_points.geojson',
#       2               properties=['facilityzip','major_city','sum','type']
# ----> 3               ,lat='lat', lon='lng', precision=3)
#
# /opt/conda/lib/python3.6/site-packages/mapboxgl/utils.py in df_to_geojson(df, properties, lat, lon, precision, date_format, filename)
#      37         if prop not in list(df.columns):
#      38             raise ValueError(
# ---> 39                 'properties must be a valid list of column names from dataframe')
#      40         if prop in [lon, lat]:
#      41             raise ValueError(
#
# ValueError: properties must be a valid list of column names from dataframe

# %%
# Create the viz
PB_viz = GraduatedCircleViz('PB_points.geojson',
                          access_token=token,
                          color_property='type',
                          color_stops=color_stops,
                          radius_property='sum',
                          stroke_color='black',
                          stroke_width=0.5,
                          radius_stops=radius_stops,
                          center=(-95, 40),\
                          zoom=3,
                          below_layer='waterway-label')
PB_viz.show()

##legend: 1-deliver_origin, 2-deliver_dest, 3-return_origin, 4-return_dest
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid black 0.5px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRig

# %%
#Create a clustered circle map
color_stops = create_color_stops([1,10,50,100], colors='BrBG')

cluster_viz = ClusteredCircleViz('PB_points.geojson',
                          access_token=token,
                          color_stops=color_stops,
                          radius_stops=[[1,5], [10, 10], [50, 15], [100, 20]],
                          radius_default=2,
                          cluster_maxzoom=10,
                          cluster_radius=30,
                          label_size=12,
                          opacity=0.9,
                          center=(-95, 40),
                          zoom=3)

cluster_viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid grey 0.1px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRigh

# %%
# Generate color stops from colorBrewer
color_breaks1 = [0,2,4,6,8,100]
color_stops1 = create_color_stops(color_breaks1, colors='YlGnBu')

# %%
sample_viz = GraduatedCircleViz('random_point_northeast_100.geojson',
                          access_token=token,
                          color_property='ID',
                          color_stops=color_stops1,
                          stroke_color='black',
                          stroke_width=0.5,
                          center=(-95, 40),
                          zoom=3,
                          below_layer='waterway-label')
sample_viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid black 0.5px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRig

# %%
sample_viz1 = GraduatedCircleViz('sample.geojson',
                          access_token=token,
                          color_property='ID',
                          color_stops=color_stops1,
                          stroke_color='black',
                          stroke_width=0.5,
                          center=(-95, 40),
                          zoom=3,
                          below_layer='waterway-label')
sample_viz1.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.51.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
# </style>
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid black 0.5px; }
# </style>
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#
#     // create legend
#     var legend = document.createElement('div');
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#
#     legend.id = 'legend';
#     document.body.appendChild(legend);
#
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ';
#         var gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-points-value-' + p)) {
#             //update the legend if it already exists
#             document.getElementById('legend-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-points-value-' + p;
#
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-points-value-' + p)
#
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             if (keys[i]) {
#                 keys[i].classList.add('bordered');
#             }
#         }
#         var gradientBars = document.getElementsByClassName('gradient-bar');
#         for (var i=0; i < keys.length; i++) {
#             if (gradientBars[i]) {
#                 gradientBars[i].classList.add('bordered');
#             }
#         }
#     }
#
#     // update right-margin for compact Mapbox attribution based on calculated legend width
#     var attribMargin = legend.offsetWidth + 15;
#     document.getElementsByClassName('mapboxgl-ctrl-attrib')[0].style.marginRig
