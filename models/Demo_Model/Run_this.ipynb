# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models/Demo_Model && pyomo solve Model_v1-Copy1.py Data_demo-Copy1.dat --solver=glpk --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Creating model
# [    1.31] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmpvlwherxq.glpk.raw --wglp /tmp/tmp0kaoslyn.glpk.glp --cpxlp
#  /tmp/tmpqax7gfff.pyomo.lp
# Reading problem data from '/tmp/tmpqax7gfff.pyomo.lp'...
# /tmp/tmpqax7gfff.pyomo.lp:143811: warning: lower bound of variable 'x1' redefined
# /tmp/tmpqax7gfff.pyomo.lp:143811: warning: upper bound of variable 'x1' redefined
# 5834 rows, 15614 columns, 102944 non-zeros
# 451 integer variables, 90 of which are binary
# 143901 lines were read
# Writing problem data to '/tmp/tmp0kaoslyn.glpk.glp'...
# 152786 lines were written
# GLPK Integer Optimizer, v4.60
# 5834 rows, 15614 columns, 102944 non-zeros
# 451 integer variables, 90 of which are binary
# Preprocessing...
# 5590 rows, 14443 columns, 94373 non-zeros
# ...

# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models/Demo_Model && pyomo solve Model_v1-Copy1.py Data_demo.dat --solver=gurobi --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Creating model
# [    0.08] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmpnzy0xjj6.glpk.raw --wglp /tmp/tmpb3y3921x.glpk.glp --cpxlp
#  /tmp/tmpggxmidnp.pyomo.lp
# Reading problem data from '/tmp/tmpggxmidnp.pyomo.lp'...
# /tmp/tmpggxmidnp.pyomo.lp:3579: warning: lower bound of variable 'x1' redefined
# /tmp/tmpggxmidnp.pyomo.lp:3579: warning: upper bound of variable 'x1' redefined
# 158 rows, 434 columns, 2204 non-zeros
# 139 integer variables, 90 of which are binary
# 3669 lines were read
# Writing problem data to '/tmp/tmpb3y3921x.glpk.glp'...
# 3686 lines were written
# GLPK Integer Optimizer, v4.60
# 158 rows, 434 columns, 2204 non-zeros
# 139 integer variables, 90 of which are binary
# Preprocessing...
# 30 constraint coefficient(s) were reduced
# 153 rows, 403 columns, 2078 non-zeros
# ...
