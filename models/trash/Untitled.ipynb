# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models/UntitledFolder && pyomo solve Model_v1-Copy2.py Data_demo-Copy1.dat --solver=glpk --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Creating model
# [    2.94] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmppl514upc.glpk.raw --wglp /tmp/tmpfqbwcycc.glpk.glp --cpxlp
#  /tmp/tmp7r0eyemz.pyomo.lp
# Reading problem data from '/tmp/tmp7r0eyemz.pyomo.lp'...
# /tmp/tmp7r0eyemz.pyomo.lp:314451: warning: lower bound of variable 'x1' redefined
# /tmp/tmp7r0eyemz.pyomo.lp:314451: warning: upper bound of variable 'x1' redefined
# 14108 rows, 20833 columns, 233993 non-zeros
# 756 integer variables, 180 of which are binary
# 314631 lines were read
# Writing problem data to '/tmp/tmpfqbwcycc.glpk.glp'...
# 319928 lines were written
# GLPK Integer Optimizer, v4.60
# 14108 rows, 20833 columns, 233993 non-zeros
# 756 integer variables, 180 of which are binary
# Preprocessing...
# 120 constraint coefficient(s) were reduced
# ...
