# %% [markdown]
# ## Model Version 1

# %%
! pip install pyomo
# Out:
# Requirement already satisfied: pyomo in /opt/conda/lib/python3.6/site-packages (5.6)
# Requirement already satisfied: PyUtilib>=5.6.4 in /opt/conda/lib/python3.6/site-packages (from pyomo) (5.6.4)
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.6/site-packages (from pyomo) (1.4.3)
# Requirement already satisfied: ply in /opt/conda/lib/python3.6/site-packages (from pyomo) (3.11)
# Requirement already satisfied: six>=1.4 in /opt/conda/lib/python3.6/site-packages (from pyomo) (1.11.0)
# Requirement already satisfied: nose in /opt/conda/lib/python3.6/site-packages (from PyUtilib>=5.6.4->pyomo) (1.3.7)

# %% [markdown]
# ## Create Model

# %%
# Import of the pyomo module
from pyomo.environ import *
 
# Creation of a Concrete Model
model = ConcreteModel()

# %% [markdown]
# ## Declare Constant

# %%
# declare constant
Max_Capital_Cost=15000000
Mile_Cost=4
Truck_Size=6000
###need input
Load_Cost=0.46
###need input
Unload_Cost=0.46
Hops=2
Fixed_Trucks_Cost=550

M=1000000000000

# %% [markdown]
# ## Declare Set

# %%
# declare set
## Define sets ##
#  Sets
#       L   All location   / Syracuse, NY, Buffalo, Elizabeth, Ithaca /
#       I   Customer warehouse          / Syracuse / ;
#       J   PB facility   /  NY, Buffalo, Elizabeth /
#       K   USPS or Courier hubs          / Ithaca / ;
#       I   Customer warehouse          / Syracuse / ;
#       h   hops day  /  0,1,2 / ;
#       S   PB facility sizes         / small, medium, large / ;
#       T   PB facility types   /  deliver, return, both / ;
#       F   PB facility features         / ingest, both / ;


model.L=Set(initialize=['Syracuse','NY','Buffalo','Elizabeth','Ithaca'])
model.I=Set(initialize=['Syracuse'])
model.J=Set(initialize=['NY','Buffalo','Elizabeth'])
model.K=Set(initialize=['Ithaca'])
model.S=Set(initialize=['small','medium','large'])
model.T=Set(initialize=['deliver','return','both'])
model.F=Set(initialize=['ingest','both'])

# %% [markdown]
# ## Declare Parameters

# %%
## Define parameters ##
#   Parameters
#       capacity(j,s,t,f)  amount of capital needed to build a hub at location J, size S, type T, feature F;
#       utility(j,s,t,f) Operating cost for a hub;
#       distance(l,l') distance between location l and location l';
#       hub_capacity(s) hub capacity of different size;
#       deliver(i,k)  the number of deliver packages from i to k;
#       repackage(k,i)  the number of return packages from k to i;
#       sorting(j)      the sorting cost in location j

## for loop create capacity_tab when data is available
#capacity_tab={('NY','small','deliver', 'ingest'):10000}
def capacity_init(model, J, S, T, F):
    if S=="small":
        return 1000000
    elif S=="medium":
        return 4000000
    elif S=="large":
        return 10000000
    #return 20000
model.capital = Param(model.J,model.S,model.T, model.F,initialize=capacity_init)

## for loop create utility_tab when data is available
#utility_tab={('NY','small','deliver', 'ingest'):10000}
def utility_init(model, J, S, T, F):
    return 500
model.utility = Param(model.J,model.S,model.T, model.F,initialize=utility_init)

## for loop create dis_tab when data is available
#dis_tab={('NY','Buffalo'):600,('NY','Elizabeth'):100,('Ithaca','NY'):500}
def dis_init(model, L, L1):
    return 10
model.distance = Param(model.L,model.L,initialize=dis_init)

## Hub Capacity
model.hub_capacity=Param(model.S,initialize={'small':4800000,'medium':14400000,'large':28800000})

def package(model, l, l1):
    return 0
model.package = Param(model.I|model.K,model.I|model.K,initialize=package)

def max_trans_cost_init(model,l,l1):
    return max(Fixed_Trucks_Cost, model.distance[l,l1]*Mile_Cost)
model.max_trans_cost = Param(model.L,model.L,initialize = max_trans_cost_init)
## The number of deliver packages from i to j
## for loop create deliver_tab
#deliver_tab={('Syracuse','Ithaca'):0}
#def deliver_init(model, I,K):
#    return 0
#model.deliver = Param(model.I,model.K,initialize=deliver_init)

## The number of deliver packages from i to j
## for loop create deliver_tab
#repackage_tab={('Ithaca','Syracuse'):0}
#def repackage_init(model, K, I):
#    return 0
#model.repackage = Param(model.K,model.I,initialize=repackage_init)

## Sorting cost
def sorting_init(model, J):
    return 10
model.sorting = Param(model.J,initialize=sorting_init)

# %% [markdown]
# ## Declare Variable

# %%
## Define variables ##
#  Variables
#       y(j,s,t,f)  Binary variable indicates whether to open a facility
#       truck(l,l)       the number of truck from l to l ;
#       n(l,l',l'',h)   the number of packages at current location l 
                     #going to location l' next, with a final destination of l'' and h hops left.
model.y=Var(model.J,model.S,model.T,model.F, within=Binary)
model.truck=Var(model.L,model.L, within=NonNegativeIntegers)
model.n=Var(model.L,model.L,model.L,range(Hops+1), within=NonNegativeReals)
#model.max_trans_cost = Var(model.L,model.L, within=NonNegativeReals)

# %% [markdown]
# ## Objective Function

# %%
# operations cost + transportation cost
# operations cost + transportation cost
#(2)
def obj_expression(model):
    utility_cost=sum((model.utility[j,s,t,f] * model.y[j,s,t,f]) for j in model.J for s in model.S for t in model.T for f in model.F)
    loading_cost=sum((Load_Cost * model.n[j,l,l1,h]) for j in model.J for l in model.L for l1 in (model.I|model.K) for h in range(0,Hops+1))
    unloading_cost=sum((Unload_Cost * model.n[l,j,l1,h]) for l in model.L for j in model.J for l1 in (model.I|model.K) for h in range(0,Hops+1)) 
    sorting_cost=sum((model.sorting[j] * model.n[j,k,k,h]) for j in model.J for k in model.K for h in range(0,Hops+1)) 
    transportation_cost=sum((model.max_trans_cost[l,l1] * model.truck[l,l1]) for l in model.L for l1 in model.L) #(3)
    return utility_cost + loading_cost + unloading_cost + sorting_cost + transportation_cost
model.OBJ = Objective(rule=obj_expression, sense = minimize, doc='Define objective function')

# %%
model.pprint()
# Out:
# 26 Set Declarations
#     F : Dim=0, Dimen=1, Size=2, Domain=None, Ordered=False, Bounds=None
#         ['both', 'ingest']
#     I : Dim=0, Dimen=1, Size=1, Domain=None, Ordered=False, Bounds=None
#         ['Syracuse']
#     J : Dim=0, Dimen=1, Size=3, Domain=None, Ordered=False, Bounds=None
#         ['Buffalo', 'Elizabeth', 'NY']
#     K : Dim=0, Dimen=1, Size=1, Domain=None, Ordered=False, Bounds=None
#         ['Ithaca']
#     L : Dim=0, Dimen=1, Size=5, Domain=None, Ordered=False, Bounds=None
#         ['Buffalo', 'Elizabeth', 'Ithaca', 'NY', 'Syracuse']
#     S : Dim=0, Dimen=1, Size=3, Domain=None, Ordered=False, Bounds=None
#         ['large', 'medium', 'small']
#     T : Dim=0, Dimen=1, Size=3, Domain=None, Ordered=False, Bounds=None
#         ['both', 'deliver', 'return']
#     capital_index : Dim=0, Dimen=4, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     capital_index_index_0 : Dim=0, Dimen=3, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     capital_index_index_0_index_0 : Dim=0, Dimen=2, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     distance_index : Dim=0, Dimen=2, Size=25, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     max_trans_cost_index : Dim=0, Dimen=2, Size=25, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     n_index : Dim=0, Dimen=4, Size=375, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     n_index_3 : Dim=0, Dimen=1, Size=3, Domain=None, Ordered=False, Bounds=(0, 2)
#         [0, 1, 2]
#     n_index_index_0 : Dim=0, Dimen=3, Size=375, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     n_index_index_0_index_0 : Dim=0, Dimen=2, Size=375, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     package_index : Dim=0, Dimen=2, Size=4, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     package_index_0 : Dim=0, Dimen=1, Size=2, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     package_index_1 : Dim=0, Dimen=1, Size=2, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     truck_index : Dim=0, Dimen=2, Size=25, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     utility_index : Dim=0, Dimen=4, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     utility_index_index_0 : Dim=0, Dimen=3, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     utility_index_index_0_index_0 : Dim=0, Dimen=2, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     y_index : Dim=0, Dimen=4, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     y_index_index_0 : Dim=0, Dimen=3, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     y_index_index_0_index_0 : Dim=0, Dimen=2, Size=54, Domain=None, Ordered=False, Bounds=None
#         Virtual
#
# 7 Param Declarations
#     capital : Size=54, Index=capital_index, Domain=Any, Default=None, Mutable=False
#         Key                                          : Value
#                 ('Buffalo', 'large', 'both', 'both') : 10000000
#               ('Buffalo', 'large', 'both', 'ingest') : 10000000
#              ('Buffalo', 'large', 'deliver', 'both') : 10000000
#            ('Buffalo', 'large', 'deliver', 'ingest') : 10000000
#               ('Buffalo', 'large', 'return', 'both') : 10000000
#             ('Buffalo', 'large', 'return', 'ingest') : 10000000
#                ('Buffalo', 'medium', 'both', 'both') :  4000000
#              ('Buffalo', 'medium', 'both', 'ingest') :  4000000
#             ('Buffalo', 'medium', 'deliver', 'both') :  4000000
#           ('Buffalo', 'medium', 'deliver', 'ingest') :  4000000
#              ('Buffalo', 'medium', 'return', 'both') :  4000000
#            ('Buffalo', 'medium', 'return', 'ingest') :  4000000
#                 ('Buffalo', 'small', 'both', 'both') :  1000000
#               ('Buffalo', 'small', 'both', 'ingest') :  1000000
#              ('Buffalo', 'small', 'deliver', 'both') :  1000000
#            ('Buffalo', 'small', 'deliver', 'ingest') :  1000000
#               ('Buffalo', 'small', 'return', 'both') :  1000000
#             ('Buffalo', 'small', 'return', 'ingest') :  1000000
#               ('Elizabeth', 'large', 'both', 'both') : 10000000
#             ('Elizabeth', 'large', 'both', 'ingest') : 10000000
#            ('Elizabeth', 'large', 'deliver', 'both') : 10000000
#          ('Elizabeth', 'large', 'deliver', 'ingest') : 10000000
#             ('Elizabeth', 'large', 'return', 'both') : 10000000
#           ('Elizabeth', 'large', 'return', 'ingest') : 10000000
#              ('Elizabeth', 'medium', 'both', 'both') :  4000000
#            ('Elizabeth', 'medium', 'both', 'ingest') :  4000000
#           ('Elizabeth', 'medium', 'deliver', 'both') :  4000000
#         ('Elizabeth', 'medium', 'deliver', 'ingest') :  4000000
#            ('Elizabeth', 'medium', 'return', 'both') :  4000000
#          ('Elizabeth', 'medium', 'return', 'ingest') :  4000000
#               ('Elizabeth', 'small', 'both', 'both') :  1000000
#             ('Elizabeth', 'small', 'both', 'ingest') :  1000000
#            ('Elizabeth', 'small', 'deliver', 'both') :  1000000
#          ('Elizabeth', 'small', 'deliver', 'ingest') :  1000000
#             ('Elizabeth', 'small', 'return', 'both') :  1000000
#           ('Elizabeth', 'small', 'return', 'ingest') :  1000000
#                      ('NY', 'large', 'both', 'both') : 10000000
#                    ('NY', 'large', 'both', 'ingest') : 10000000
#                   ('NY', 'large', 'deliver', 'both') : 10000000
#                 ('NY', 'large', 'deliver', 'ingest') : 10000000
#                    ('NY', 'large', 'return', 'both') : 10000000
#                  ('NY', 'large', 'return', 'ingest') : 10000000
#                     ('NY', 'medium', 'both', 'both') :  4000000
#                   ('NY', 'medium', 'both', 'ingest') :  4000000
#                  ('NY', 'medium', 'deliver', 'both') :  4000000
#                ('NY', 'medium', 'deliver', 'ingest') :  4000000
#                   ('NY', 'medium', 'return', 'both') :  4000000
#                 ('NY', 'medium', 'return', 'ingest') :  4000000
#                      ('NY', 'small', 'both', 'both') :  1000000
#                    ('NY', 'small', 'both', 'ingest') :  1000000
#                   ('NY', 'small', 'deliver', 'both') :  1000000
#                 ('NY', 'small', 'deliver', 'ingest') :  1000000
#                    ('NY', 'small', 'return', 'both') :  1000000
#                  ('NY', 'small', 'return', 'ingest') :  1000000
#     distance : Size=25, Index=distance_index, Domain=Any, Default=None, Mutable=False
#         Key                        : Value
#             ('Buffalo', 'Buffalo') :    10
#           ('Buffalo', 'Elizabeth') :    10
#              ('Buffalo', 'Ithaca') :    10
#                  ('Buffalo', 'NY') :    10
#            ('Buffalo', 'Syracuse') :    10
#           ('Elizabeth', 'Buffalo') :    10
#         ('Elizabeth', 'Elizabeth') :    10
#            ('Elizabeth', 'Ithaca') :    10
#                ('Elizabeth', 'NY') :    10
#          ('Elizabeth', 'Syracuse') :    10
#              ('Ithaca', 'Buffalo') :    10
#            ('Ithaca', 'Elizabeth') :    10
#               ('Ithaca', 'Ithaca') :    10
#                   ('Ithaca', 'NY') :    10
#             ('Ithaca', 'Syracuse') :    10
#                  ('NY', 'Buffalo') :    10
#                ('NY', 'Elizabeth') :    10
#                   ('NY', 'Ithaca') :    10
#                       ('NY', 'NY') :    10
#                 ('NY', 'Syracuse') :    10
#            ('Syracuse', 'Buffalo') :    10
#          ('Syracuse', 'Elizabeth') :    10
#             ('Syracuse', 'Ithaca') :    10
#                 ('Syracuse', 'NY') :    10
#           ('Syracuse', 'Syracuse') :    10
#     hub_capacity : Size=3, Index=S, Domain=Any, Default=None, Mutable=False
#         Key    : Value
#          large : 28800000
#         medium : 14400000
#          small :  4800000
#     max_trans_cost : Size=25, Index=max_trans_cost_index, Domain=Any, Default=None, Mutable=False
#         Key                        : Value
#             ('Buffalo', 'Buffalo') :   550
#           ('Buffalo', 'Elizabeth') :   550
#              ('Buffalo', 'Ithaca') :   550
#                  ('Buffalo', 'NY') :   550
#            ('Buffalo', 'Syracuse') :   550
#           ('Elizabeth', 'Buffalo') :   550
#         ('Elizabeth', 'Elizabeth') :   550
#            ('Elizabeth', 'Ithaca') :   550
#                ('Elizabeth', 'NY') :   550
#          ('Elizabeth', 'Syracuse') :   550
#              ('Ithaca', 'Buffalo') :   550
#            ('Ithaca', 'Elizabeth') :   550
#               ('Ithaca', 'Ithaca') :   550
#                   ('Ithaca', 'NY') :   550
#             ('Ithaca', 'Syracuse') :   550
#                  ('NY', 'Buffalo') :   550
#                ('NY', 'Elizabeth') :   550
#                   ('NY', 'Ithaca') :   550
#                       ('NY', 'NY') :   550
#                 ('NY', 'Syracuse') :   550
#            ('Syracuse', 'Buffalo') :   550
#          ('Syracuse', 'Elizabeth') :   550
#             ('Syracuse', 'Ithaca') :   550
#                 ('Syracuse', 'NY') :   550
#           ('Syracuse', 'Syracuse') :   550
#     package : Size=4, Index=package_index, Domain=Any, Default=None, Mutable=False
#         Key                      : Value
#             ('Ithaca', 'Ithaca') :     0
#           ('Ithaca', 'Syracuse') :     0
#           ('Syracuse', 'Ithaca') :     0
#         ('Syracuse', 'Syracuse') :     0
#     sorting : Size=3, Index=J, Domain=Any, Default=None, Mutable=False
#         Key       : Value
#           Buffalo :    10
#         Elizabeth :    10
#                NY :    10
#     utility : Size=54, Index=utility_index, Domain=Any, Default=None, Mutable=False
#         Key                                          : Value
#                 ('Buffalo', 'large', 'both', 'both') :   500
#               ('Buffalo', 'large', 'both', 'ingest') :   500
#              ('Buffalo', 'large', 'deliver', 'both') :   500
#            ('Buffalo', 'large', 'deliver', 'ingest') :   500
#               ('Buffalo', 'large', 'return', 'both') :   500
#             ('Buffalo', 'large', 'return', 'ingest') :   500
#                ('Buffalo', 'medium', 'both', 'both') :   500
#              ('Buffalo', 'medium', 'both', 'ingest') :   500
#             ('Buffalo', 'medium', 'deliver', 'both') :   500
#           ('Buffalo', 'medium', 'deliver', 'ingest') :   500
#              ('Buffalo', 'medium', 'return', 'both') :   500
#            ('Buffalo', 'medium', 'return', 'ingest') :   500
#                 ('Buffalo', 'small', 'both', 'both') :   500
#               ('Buffalo', 'small', 'both', 'ingest') :   500
#              ('Buffalo', 'small', 'deliver', 'both') :   500
#            ('Buffalo', 'small', 'deliver', 'ingest') :   500
#               ('Buffalo', 'small', 'return', 'both') :   500
#             ('Buffalo', 'small', 'return', 'ingest') :   500
#               ('Elizabeth', 'large', 'both', 'both') :   500
#             ('Elizabeth', 'large', 'both', 'ingest') :   500
#            ('Elizabeth', 'large', 'deliver', 'both') :   500
#          ('Elizabeth', 'large', 'deliver', 'ingest') :   500
#             ('Elizabeth', 'large', 'return', 'both') :   500
#           ('Elizabeth', 'large', 'return', 'ingest') :   500
#              ('Elizabeth', 'medium', 'both', 'both') :   500
#            ('Elizabeth', 'medium', 'both', 'ingest') :   500
#           ('Elizabeth', 'medium', 'deliver', 'both') :   500
#         ('Elizabeth', 'medium', 'deliver', 'ingest') :   500
#            ('Elizabeth', 'medium', 'return', 'both') :   500
#          ('Elizabeth', 'medium', 'return', 'ingest') :   500
#               ('Elizabeth', 'small', 'both', 'both') :   500
#             ('Elizabeth', 'small', 'both', 'ingest') :   500
#            ('Elizabeth', 'small', 'deliver', 'both') :   500
#          ('Elizabeth', 'small', 'deliver', 'ingest') :   500
#             ('Elizabeth', 'small', 'return', 'both') :   500
#           ('Elizabeth', 'small', 'return', 'ingest') :   500
#                      ('NY', 'large', 'both', 'both') :   500
#                    ('NY', 'large', 'both', 'ingest') :   500
#                   ('NY', 'large', 'deliver', 'both') :   500
#                 ('NY', 'large', 'deliver', 'ingest') :   500
#                    ('NY', 'large', 'return', 'both') :   500
#                  ('NY', 'large', 'return', 'ingest') :   500
#                     ('NY', 'medium', 'both', 'both') :   500
#                   ('NY', 'medium', 'both', 'ingest') :   500
#                  ('NY', 'medium', 'deliver', 'both') :   500
#                ('NY', 'medium', 'deliver', 'ingest') :   500
#                   ('NY', 'medium', 'return', 'both') :   500
#                 ('NY', 'medium', 'return', 'ingest') :   500
#                      ('NY', 'small', 'both', 'both') :   500
#                    ('NY', 'small', 'both', 'ingest') :   500
#                   ('NY', 'small', 'deliver', 'both') :   500
#                 ('NY', 'small', 'deliver', 'ingest') :   500
#                    ('NY', 'small', 'return', 'both') :   500
#                  ('NY', 'small', 'return', 'ingest') :   500
#
# 3 Var Declarations
#     n : Size=375, Index=n_index
#         Key                                        : Lower : Value : Upper : Fixed : Stale : Domain
#               ('Buffalo', 'Buffalo', 'Buffalo', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#               ('Buffalo', 'Buffalo', 'Buffalo', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#               ('Buffalo', 'Buffalo', 'Buffalo', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Buffalo', 'Elizabeth', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Buffalo', 'Elizabeth', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Buffalo', 'Elizabeth', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#                ('Buffalo', 'Buffalo', 'Ithaca', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#                ('Buffalo', 'Buffalo', 'Ithaca', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#                ('Buffalo', 'Buffalo', 'Ithaca', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#                    ('Buffalo', 'Buffalo', 'NY', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#                    ('Buffalo', 'Buffalo', 'NY', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#                    ('Buffalo', 'Buffalo', 'NY', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#              ('Buffalo', 'Buffalo', 'Syracuse', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#              ('Buffalo', 'Buffalo', 'Syracuse', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#              ('Buffalo', 'Buffalo', 'Syracuse', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Elizabeth', 'Buffalo', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Elizabeth', 'Buffalo', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#             ('Buffalo', 'Elizabeth', 'Buffalo', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#           ('Buffalo', 'Elizabeth', 'Elizabeth', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#           ('Buffalo', 'Elizabeth', 'Elizabeth', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#           ('Buffalo', 'Elizabeth', 'Elizabeth', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#              ('Buffalo', 'Elizabeth', 'Ithaca', 0) :     0 :  None :  None : False :  True : NonNegativeReals
#              ('Buffalo', 'Elizabeth', 'Ithaca', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#          ('Syracuse', 'Elizabeth') :     0 :  None :  None : False :  True : NonNegativeIntegers
#             ('Syracuse', 'Ithaca') :     0 :  None :  None : False :  True : NonNegativeIntegers
#                 ('Syracuse', 'NY') :     0 :  None :  None : False :  True : NonNegativeIntegers
#           ('Syracuse', 'Syracuse') :     0 :  None :  None : False :  True : NonNegativeIntegers
#     y : Size=54, Index=y_index
#         Key                                          : Lower : Value : Upper : Fixed : Stale : Domain
#                 ('Buffalo', 'large', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#               ('Buffalo', 'large', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#              ('Buffalo', 'large', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#            ('Buffalo', 'large', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#               ('Buffalo', 'large', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#             ('Buffalo', 'large', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                ('Buffalo', 'medium', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#              ('Buffalo', 'medium', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#             ('Buffalo', 'medium', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#           ('Buffalo', 'medium', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#              ('Buffalo', 'medium', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#            ('Buffalo', 'medium', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                 ('Buffalo', 'small', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#               ('Buffalo', 'small', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#              ('Buffalo', 'small', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#            ('Buffalo', 'small', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#               ('Buffalo', 'small', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#             ('Buffalo', 'small', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#               ('Elizabeth', 'large', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#             ('Elizabeth', 'large', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#            ('Elizabeth', 'large', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#          ('Elizabeth', 'large', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#             ('Elizabeth', 'large', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#           ('Elizabeth', 'large', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#              ('Elizabeth', 'medium', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#            ('Elizabeth', 'medium', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#           ('Elizabeth', 'medium', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#         ('Elizabeth', 'medium', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#            ('Elizabeth', 'medium', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#          ('Elizabeth', 'medium', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#               ('Elizabeth', 'small', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#             ('Elizabeth', 'small', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#            ('Elizabeth', 'small', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#          ('Elizabeth', 'small', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#             ('Elizabeth', 'small', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#           ('Elizabeth', 'small', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                      ('NY', 'large', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#                    ('NY', 'large', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                   ('NY', 'large', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#                 ('NY', 'large', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                    ('NY', 'large', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#                  ('NY', 'large', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                     ('NY', 'medium', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#                   ('NY', 'medium', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                  ('NY', 'medium', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#                ('NY', 'medium', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                   ('NY', 'medium', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#                 ('NY', 'medium', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                      ('NY', 'small', 'both', 'both') :     0 :  None :     1 : False :  True : Binary
#                    ('NY', 'small', 'both', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                   ('NY', 'small', 'deliver', 'both') :     0 :  None :     1 : False :  True : Binary
#                 ('NY', 'small', 'deliver', 'ingest') :     0 :  None :     1 : False :  True : Binary
#                    ('NY', 'small', 'return', 'both') :     0 :  None :     1 : False :  True : Binary
#                  ('NY', 'small', 'return', 'ingest') :     0 :  None :     1 : False :  True : Binary
#
# 1 Objective Declarations
#     OBJ : Define objective function
#         Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 500*y[Buffalo,medium,deliver,ingest] + 500*y[Buffalo,medium,deliver,both] + 500*y[Buffalo,medium,both,ingest] + 500*y[Buffalo,medium,both,both] + 500*y[Buffalo,medium,return,ingest] + 500*y[Buffalo,medium,return,both] + 500*y[Buffalo,large,deliver,ingest] + 500*y[Buffalo,large,deliver,both] + 500*y[Buffalo,large,both,ingest] + 500*y[Buffalo,large,both,both] + 500*y[Buffalo,large,return,ingest] + 500*y[Buffalo,large,return,both] + 500*y[Buffalo,small,deliver,ingest] + 500*y[Buffalo,small,deliver,both] + 500*y[Buffalo,small,both,ingest] + 500*y[Buffalo,small,both,both] + 500*y[Buffalo,small,return,ingest] + 500*y[Buffalo,small,return,both] + 500*y[Elizabeth,medium,deliver,ingest] + 500*y[Elizabeth,medium,deliver,both] + 500*y[Elizabeth,medium,both,ingest] + 500*y[Elizabeth,medium,both,both] + 500*y[Elizabeth,medium,return,ingest] + 500*y[Elizabeth,medium,return,both] + 500*y[Elizabeth,large,deliver,ingest] + 500*y[Elizabeth,large,deliver,both] + 500*y[Elizabeth,large,both,ingest] + 500*y[Elizabeth,large,both,both] + 500*y[Elizabeth,large,return,ingest] + 500*y[Elizabeth,large,return,both] + 500*y[Elizabeth,small,deliver,ingest] + 500*y[Elizabeth,small,deliver,both] + 500*y[Elizabeth,small,both,ingest] + 500*y[Elizabeth,small,both,both] + 500*y[Elizabeth,small,return,ingest] + 500*y[Elizabeth,small,return,both] + 500*y[NY,medium,deliver,ingest] + 500*y[NY,medium,deliver,both] + 500*y[NY,medium,both,ingest] + 500*y[NY,medium,both,both] + 500*y[NY,medium,return,ingest] + 500*y[NY,medium,return,both] + 500*y[NY,large,deliver,ingest] + 500*y[NY,large,deliver,both] + 500*y[NY,large,both,ingest] + 500*y[NY,large,both,both] + 500*y[NY,large,return,ingest] + 500*y[NY,large,return,both] + 500*y[NY,small,deliver,ingest] + 500*y[NY,small,deliver,both] + 500*y[NY,small,both,ingest] + 500*y[NY,small,both,both] + 500*y[NY,small,return,ingest] + 500*y[NY,small,return,both] + 0.46*n[Buffalo,Elizabeth,Syracuse,0] + 0.46*n[Buffalo,Elizabeth,Syracuse,1] + 0.46*n[Buffalo,Elizabeth,Syracuse,2] + 0.46*n[Buffalo,Elizabeth,Ithaca,0] + 0.46*n[Buffalo,Elizabeth,Ithaca,1] + 0.46*n[Buffalo,Elizabeth,Ithaca,2] + 0.46*n[Buffalo,Ithaca,Syracuse,0] + 0.46*n[Buffalo,Ithaca,Syracuse,1] + 0.46*n[Buffalo,Ithaca,Syracuse,2] + 0.46*n[Buffalo,Ithaca,Ithaca,0] + 0.46*n[Buffalo,Ithaca,Ithaca,1] + 0.46*n[Buffalo,Ithaca,Ithaca,2] + 0.46*n[Buffalo,NY,Syracuse,0] + 0.46*n[Buffalo,NY,Syracuse,1] + 0.46*n[Buffalo,NY,Syracuse,2] + 0.46*n[Buffalo,NY,Ithaca,0] + 0.46*n[Buffalo,NY,Ithaca,1] + 0.46*n[Buffalo,NY,Ithaca,2] + 0.46*n[Buffalo,Buffalo,Syracuse,0] + 0.46*n[Buffalo,Buffalo,Syracuse,1] + 0.46*n[Buffalo,Buffalo,Syracuse,2] + 0.46*n[Buffalo,Buffalo,Ithaca,0] + 0.46*n[Buffalo,Buffalo,Ithaca,1] + 0.46*n[Buffalo,Buffalo,Ithaca,2] + 0.46*n[Buffalo,Syracuse,Syracuse,0] + 0.46*n[Buffalo,Syracuse,Syracuse,1] + 0.46*n[Buffalo,Syracuse,Syracuse,2] + 0.46*n[Buffalo,Syracuse,Ithaca,0] + 0.46*n[Buffalo,Syracuse,Ithaca,1] + 0.46*n[Buffalo,Syracuse,Ithaca,2] + 0.46*n[Elizabeth,Elizabeth,Syracuse,0] + 0.46*n[Elizabeth,Elizabeth,Syracuse,1] + 0.46*n[Elizabeth,Elizabeth,Syracuse,2] + 0.46*n[Elizabeth,Elizabeth,Ithaca,0] + 0.46*n[Elizabeth,Elizabeth,Ithaca,1] + 0.46*n[Elizabeth,Elizabeth,Ithaca,2] + 0.46*n[Elizabeth,Ithaca,Syracuse,0] + 0.46*n[Elizabeth,Ithaca,Syracuse,1] + 0.46*n[Elizabeth,Ithaca,Syracuse,2] + 0.46*n[Elizabeth,Ithaca,Ithaca,0] + 0.46*n[Elizabeth,Ithaca,Ithaca,1] + 0.46*n[Elizabeth,Ithaca,Ithaca,2] + 0.46*n[Elizabeth,NY,Syracuse,0] + 0.46*n[Elizabeth,NY,Syracuse,1] + 0.46*n[Elizabeth,NY,Syracuse,2] + 0.46*n[Elizabeth,NY,Ithaca,0] + 0.46*n[Elizabeth,NY,Ithaca,1] + 0.46*n[Elizabeth,NY,Ithaca,2] + 0.46*n[Elizabeth,Buffalo,Syracuse,0] + 0.46*n[Elizabeth,Buffalo,Syracuse,1] + 0.46*n[Elizabeth,Buffalo,Syracuse,2] + 0.46*n[Elizabeth,Buffalo,Ithaca,0] + 0.46*n[Elizabeth,Buffalo,Ithaca,1] + 0.46*n[Elizabeth,Buffalo,Ithaca,2] + 0.46*n[Elizabeth,Syracuse,Syracuse,0] + 0.46*n[Elizabeth,Syracuse,Syracuse,1] + 0.46*n[Elizabeth,Syracuse,Syracuse,2] + 0.46* ...
#
# 37 Declarations: L I J K S T F capital_index_index_0_index_0 capital_index_index_0 capital_index capital utility_index_index_0_index_0 utility_index_index_0 utility_index utility distance_index distance hub_capacity package_index_0 package_index_1 package_index package max_trans_cost_index max_trans_cost sorting y_index_index_0_index_0 y_index_index_0 y_index y truck_index truck n_index_3 n_index_index_0_index_0 n_index_index_0 n_index n OBJ

# %% [markdown]
# ## Constraints

# %%
## Define contrains ##
# capital_constrains   the sum of the capital cost

#(1)
def capital_constraints(model):
    total_cost=0
    for j in model.J:
        for s in model.S:
            for t in model.T:
                for f in model.F:
                    total_cost+=model.capital[j,s,t,f]*model.y[j,s,t,f]
    return total_cost<=Max_Capital_Cost
model.max_cap = Constraint( rule = capital_constraints, doc = "max capital constraint")

# %%
#(4)
#def max_trans_cost_rule(model,l,l1):
#    return model.max_trans_cost[l,l1]>=model.distance[l,l1]*Mile_Cost
#model.max_trans_con=Constraint(model.L,model.L,rule=max_trans_cost_rule,doc="transportation cost constraint")

# %%
#(5)
#def max_trans_cost_rule2(model,l,l1):
#    return model.max_trans_cost[l,l1]>=Fixed_Trucks_Cost
#model.max_trans_con2=Constraint(model.L,model.L,rule=max_trans_cost_rule2,doc="transportation cost constraint")

# %%
#(6)
def truck_size_constraints(model,l,l1):
    trucksize=0
    for l2 in model.I | model.K:
        for h in range(Hops):
            trucksize+=model.n[l,l1,l2,h]
    return trucksize<= Truck_Size*model.truck[l,l1]
model.truck_size_con = Constraint(model.L,model.L,rule = truck_size_constraints, doc = "truck size constraint")

# %%
#(7)
def inbound_equal_rule(model, j, h, l1):
      return (sum(model.n[l,j,l1,h] for l in model.L)
          == sum(model.n[j,l2,l1,h-1] for l2 in model.L))
model.inbound_equal = Constraint(model.J,range(1,Hops),model.I|model.K, rule = inbound_equal_rule, doc = "inbound package equal")

# %%
#(8)
#2nd demand contransts
def initialization_demand_rule(model,l,l1):
    if l == l1:
        return Constraint.Skip
    return (sum(model.n[l,j,l1,Hops] for j in model.J) == model.package[l,l1])
model.initialization_demand = Constraint(model.I|model.K,model.I|model.K,rule = initialization_demand_rule)

# %%
#(9)
def destination_demand_rule(model, l):
    return (sum(model.n[j,l,l,h] for j in model.J for h in range(0,Hops+1)) == sum(model.package[l1,l] for l1 in model.I|model.K))
model.destination_demand_rule = Constraint(model.I|model.K, rule=destination_demand_rule)

# %%
#(10)
def num_of_hubs_opened_perlocation(model,j):
    num=0
    for s in model.S:
        for t in model.T:
            for f in model.F:
                num=model.y[j,s,t,f]
                return num<=1
model.num=Constraint(model.J,rule=num_of_hubs_opened_perlocation,doc="contraint on num of hubs opened per location")

# %%
#(11)
def delivery_hub_rule(model,j,k,l):
    return (sum(model.n[l,j,k,h] for h in range(0,Hops+1))
           <= (M * sum(model.y[j,s,'deliver',f]+model.y[j,s,'deliver',f] for s in model.S for f in model.F)))
model.delivery_hub = Constraint(model.J,model.K,model.I|model.J, rule = delivery_hub_rule, doc = "ensure delivery packages handled by delivery hub")

# %%
#(12)
def delivery_sort_hub_rule(model,j,k):
    return (sum(model.n[j,k,k,h] for h in range(0,Hops+1))
           <= (M * sum(model.y[j,s,'deliver','both']+model.y[j,s,'return','both'] for s in model.S)))
model.delivery_sort_hub = Constraint(model.J,model.K, rule = delivery_sort_hub_rule, doc = "ensure last delivery packages handled by sort-delivery hub")

# %%
#(13)
def return_hub_rule(model,i,j,k,l):
    return (sum(model.n[l,j,i,h] for h in range(0,Hops+1))
           <= (M * sum(model.y[j,s,'return',f]+model.y[j,s,'return',f] for s in model.S for f in model.F)))
model.return_hub = Constraint(model.I,model.J,model.K,model.L, rule = return_hub_rule, doc = "ensure return packages handled by return hub")

# %%
#(14)
def hub_capacity_constraint(model,j):
    return sum(model.n[l,j,l1,h] for l in model.L for l1 in model.I|model.K for h in range(0,Hops+1))<=sum(model.hub_capacity[s]*model.y[j,s,t,f] for s in model.S for t in model.T for f in model.F)
model.hub_capacity_constraint=Constraint(model.J, rule=hub_capacity_constraint,doc="hub capacity constraint")

# %%
from pyomo.opt import SolverFactory
#import pyomo.environ
opt = SolverFactory("glpk")
results = opt.solve(model)
#sends results to stdout
results.write()
print("\nDisplaying Solution\n" + '-'*60)
#pyomo_postprocess(None, model, results)
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 0.0
#   Upper bound: 0.0
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 222
#   Number of nonzeros: 681
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.011852741241455078
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# ------------------------------------------------------------
