# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models && pyomo solve Model_v1-Copy1.py Data_demo.dat --solver=glpk --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.01] Creating model
# [    0.05] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmpzzj6axte.glpk.raw --wglp /tmp/tmpy62hrf12.glpk.glp --cpxlp
#  /tmp/tmpt8u5ihhc.pyomo.lp
# Reading problem data from '/tmp/tmpt8u5ihhc.pyomo.lp'...
# /tmp/tmpt8u5ihhc.pyomo.lp:1217: warning: lower bound of variable 'x1' redefined
# /tmp/tmpt8u5ihhc.pyomo.lp:1217: warning: upper bound of variable 'x1' redefined
# 50 rows, 245 columns, 673 non-zeros
# 52 integer variables, 36 of which are binary
# 1253 lines were read
# Writing problem data to '/tmp/tmpy62hrf12.glpk.glp'...
# 1346 lines were written
# GLPK Integer Optimizer, v4.60
# 50 rows, 245 columns, 673 non-zeros
# 52 integer variables, 36 of which are binary
# Preprocessing...
# 12 constraint coefficient(s) were reduced
# 49 rows, 244 columns, 672 non-zeros
# ...
