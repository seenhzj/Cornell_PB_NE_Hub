# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models && pyomo solve Model_v1-Copy1.py Data_demo-Copy2.dat --solver=glpk --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.01] Creating model
# [    2.97] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmp61kcf3qk.glpk.raw --wglp /tmp/tmpw4ndeel9.glpk.glp --cpxlp
#  /tmp/tmpmmxpspf1.pyomo.lp
# Reading problem data from '/tmp/tmpmmxpspf1.pyomo.lp'...
# /tmp/tmpmmxpspf1.pyomo.lp:385656: warning: lower bound of variable 'x1' redefined
# /tmp/tmpmmxpspf1.pyomo.lp:385656: warning: upper bound of variable 'x1' redefined
# 15640 rows, 43355 columns, 279125 non-zeros
# 766 integer variables, 90 of which are binary
# 385746 lines were read
# Writing problem data to '/tmp/tmpw4ndeel9.glpk.glp'...
# 411948 lines were written
# GLPK Integer Optimizer, v4.60
# 15640 rows, 43355 columns, 279125 non-zeros
# 766 integer variables, 90 of which are binary
# Preprocessing...
# 240 constraint coefficient(s) were reduced
# ...

# %%
# !cd /home/fusion/jupyterhub-notebooks/Cornell_PB_NE_Hub/models && pyomo solve Model_v1-Copy1.py Data_demo-Copy1.dat --solver=glpk --summary --stream-solver
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.01] Creating model
# [    1.27] Applying solver
# GLPSOL: GLPK LP/MIP Solver, v4.60
# Parameter(s) specified in the command line:
#  --write /tmp/tmpicnk9hd_.glpk.raw --wglp /tmp/tmpcx30i5xz.glpk.glp --cpxlp
#  /tmp/tmpf928kn8o.pyomo.lp
# Reading problem data from '/tmp/tmpf928kn8o.pyomo.lp'...
# /tmp/tmpf928kn8o.pyomo.lp:131901: warning: lower bound of variable 'x1' redefined
# /tmp/tmpf928kn8o.pyomo.lp:131901: warning: upper bound of variable 'x1' redefined
# 5833 rows, 11498 columns, 95153 non-zeros
# 451 integer variables, 90 of which are binary
# 131991 lines were read
# Writing problem data to '/tmp/tmpcx30i5xz.glpk.glp'...
# 136773 lines were written
# GLPK Integer Optimizer, v4.60
# 5833 rows, 11498 columns, 95153 non-zeros
# 451 integer variables, 90 of which are binary
# Preprocessing...
# 210 constraint coefficient(s) were reduced
# 5636 rows, 9922 columns, 87977 non-zeros
# ...
